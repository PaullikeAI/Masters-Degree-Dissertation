# %% [markdown]
# ### Naive Bayes Classifier - Data Testing

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.utils import resample
import pandas as pd

def format_time(seconds):
    """Formats time in seconds into hours/minutes/seconds and returns a string of the resulting time."""
    minutes = int(seconds // 60)
    hours = int(minutes // 60)
    minutes = minutes % 60
    seconds = seconds % 60
    if hours > 0:
        return f"{hours} hours, {minutes} minute{'s' if minutes != 1 else ''}, {seconds:.2f} seconds"
    if minutes > 0:
        return f"{minutes} minute{'s' if minutes != 1 else ''}, {seconds:.2f} seconds"
    return f"{seconds:.2f} seconds"

# %%
# Import the data.
df = pd.read_csv("Shield_Experience_31.03.2025_13.41.csv")
print(f"Number of experiences: {len(df)}")
# Out:
# Number of experiences: 2951771

# %%
# Split data into batches by sets of 20k. Last 20k episodes excluded, as will not train shield again at the end of training.
Batch_1_1_to_20000 = df[df['Episode'].between(1, 20000 )]
Batch_2_20001_to_40000 = df[df['Episode'].between(20001, 40000)]
Batch_3_40001_to_60000 = df[df['Episode'].between(40001, 60000)]
Batch_4_60001_to_80000 = df[df['Episode'].between(60001, 80000)]
Batch_5_80001_to_100000 = df[df['Episode'].between(80001, 100000)]

batches = [Batch_1_1_to_20000, Batch_2_20001_to_40000, Batch_3_40001_to_60000, Batch_4_60001_to_80000, Batch_5_80001_to_100000]

saff = 0
unsaff = 0

for i in batches: # Check batch sizes.
    print("Batch total: ", len(i))
    
    zeros = len(i[i['Safe'] == 0])
    print("Unsafe: ", zeros,f" - {zeros/len(i)*100:.2f}%")
    ones = len(i[i['Safe'] == 1])
    saff += ones
    unsaff += zeros
    print("Safe: ", ones, f" - {ones/len(i)*100:.2f}%", end="\n\n" )
    # Safe and unsafe for each batch.

print(f"Safe total: {saff}, {saff/(saff+unsaff)*100:.2f}%   Unsafe total: {unsaff}, {unsaff/(saff+unsaff)*100:.2f}%")
# Out:
# Batch total:  604987
# Unsafe:  19441  - 3.21%
# Safe:  585546  - 96.79%
#
# Batch total:  549861
# Unsafe:  13559  - 2.47%
# Safe:  536302  - 97.53%
#
# Batch total:  457828
# Unsafe:  3769  - 0.82%
# Safe:  454059  - 99.18%
#
# Batch total:  453604
# Unsafe:  3788  - 0.84%
# Safe:  449816  - 99.16%
#
# Batch total:  450414
# Unsafe:  4301  - 0.95%
# Safe:  446113  - 99.05%
#
# Safe total: 2471836, 98.22%   Unsafe total: 44858, 1.78%

# %%
def balance_samples(df, mult=1):
    """Function to take in a dataframe of samples and balance the data by undersampling the safe states.
       Baseline make it a 1:1 Ratio.
       The mult paramater changes this. 2 means 2:1 - Safe:Unsafe
       Mult of 0 returns the original data"""
    # What it does: Randomly reduce the number of Class A samples to match Class B (e.g., 1,000 each). [Notes to delete]
    # Pros: Simple, reduces training time, balances classes perfectly.
    # Cons: Throws away a lot of data (26,000 Class A samples), potentially losing valuable patterns.
    if mult == 0:
        # Original data returned.
        return df
    
    unsafe_exps = df[df['Safe'] == 0]
    safe_exps = df[df['Safe'] == 1]

    # Undersample the safe experiences with no duplicates to match the number of unsafe ones present.
    undersampled_safe_exps = resample(safe_exps,replace=False, n_samples=int(len(unsafe_exps)*mult), random_state=6)
    
    # Combine the unsafe with undersampled safe.
    return pd.concat([unsafe_exps, undersampled_safe_exps])

# %%
# Different thresholds and safe/unsafe ratio modifiers to be tested in grid search.
ths = [0.2, 0.3, 0.4, 0.46, 0.47, 0.48, 0.49, 0.5, 0.51, 0.52, 0.53, 0.54, 0.55, 0.6, 0.7, 0.95, 0.96, 0.97, 0.975, 0.985]
mults = [0, 0.5, 0.75, 0.85, 0.9, 0.95, 1, 1.25, 1.5, 2, 3, 4, 5]

# %% [markdown]
# #### Multiomial Naive Bayes

# %%
# Train the Multiomial Naive Bayes five times with the five batches.
for mult in mults:
    print(f"Mult: {mult} ***********************************************************")
    acc_total = 0
    rec_tot = 0
    acc_total_th = 0
    rec_tot_th = 0
    classifier = MultinomialNB() # Initiate classifier
    for b_num, batch in enumerate(batches):
        # Variable/Classification Split
        X = batch.drop(df.columns[[0, 1, 11]], axis=1) # Drop columns 0, 1 and 12 (index, episode, safe)
        Y = batch["Safe"]

        # Split into Train and test set
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=6)

        # Recombine X_train and Y_train for balancing
        X_train = X_train.copy() # To nullify Pandas view warning
        X_train["Safe"] = Y_train

        # Balance the data
        balanced_data = balance_samples(X_train, mult)

        # Split out data back into X_train and Y_train again
        Y_train = balanced_data["Safe"]
        X_train = balanced_data.drop("Safe", axis=1)

        # Train Classifier
        classifier.partial_fit(X_train, Y_train, classes=[0, 1])

        # Make predictions using classifier
        Y_pred = classifier.predict(X_test)
        accuracy = accuracy_score(Y_test, Y_pred)
        recall = recall_score(Y_test, Y_pred, pos_label=0)
        acc_total += accuracy
        rec_tot += recall

    print(f"Standard: Mult {mult}    Average accuracy: {acc_total/5*100:.2f}% Average recall: {rec_tot/5*100:.2f}% {(acc_total/5*100)+(rec_tot/5*100):.2f}")

print()
print(" ___________________ With Thresholds ___________________")
for mult in mults:
    print(f"Mult: {mult} ***********************************************************")
    for th in ths:
        acc_total = 0
        rec_tot = 0
        acc_total_th = 0
        rec_tot_th = 0
        classifier = MultinomialNB() # Initiate classifier
        for b_num, batch in enumerate(batches):
            # Variable/Classification Split
            X = batch.drop(df.columns[[0, 1, 11]], axis=1) # Drop columns 0, 1 and 12 (index, episode, safe)
            Y = batch["Safe"]

            # Split into Train and test set
            X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=6)

            # Recombine X_train and Y_train for balancing
            X_train = X_train.copy() # To nullify Pandas view warning
            X_train["Safe"] = Y_train

            # Balance the data
            balanced_data = balance_samples(X_train, mult)

            # Split out data back into X_train and Y_train again
            Y_train = balanced_data["Safe"]
            X_train = balanced_data.drop("Safe", axis=1)

            # Train Classifier
            classifier.partial_fit(X_train, Y_train, classes=[0, 1])

            # Make predictions using classifier
            Y_pred = classifier.predict(X_test)
            accuracy = accuracy_score(Y_test, Y_pred)
            recall = recall_score(Y_test, Y_pred, pos_label=0)
            acc_total += accuracy
            rec_tot += recall
            
            # Using a threshold for the safe class
            threshold = th
            Y_probs = classifier.predict_proba(X_test)
            Y_pred_custom = (Y_probs[:, 1] >= th).astype(int)
            accuracy = accuracy_score(Y_test, Y_pred_custom)
            recall = recall_score(Y_test, Y_pred_custom, pos_label=0)
            acc_total_th += accuracy
            rec_tot_th += recall
            
        print(f"Mult: {mult} Thresh: {th}  Acc: {acc_total_th/5*100:.2f}%   Recall: {rec_tot_th/5*100:.2f}% = {(acc_total_th/5*100)+(rec_tot_th/5*100):.2f}")
# Out:
# Mult: 0 ***********************************************************
# Standard: Mult 0    Average accuracy: 98.32% Average recall: 0.00% 98.32
# Mult: 0.5 ***********************************************************
# Standard: Mult 0.5    Average accuracy: 1.68% Average recall: 100.00% 101.68
# Mult: 0.75 ***********************************************************
# Standard: Mult 0.75    Average accuracy: 1.75% Average recall: 100.00% 101.75
# Mult: 0.85 ***********************************************************
# Standard: Mult 0.85    Average accuracy: 9.12% Average recall: 99.78% 108.91
# Mult: 0.9 ***********************************************************
# Standard: Mult 0.9    Average accuracy: 29.18% Average recall: 96.67% 125.85
# Mult: 0.95 ***********************************************************
# Standard: Mult 0.95    Average accuracy: 42.00% Average recall: 87.42% 129.41
# Mult: 1 ***********************************************************
# Standard: Mult 1    Average accuracy: 50.86% Average recall: 74.96% 125.83
# Mult: 1.25 ***********************************************************
# Standard: Mult 1.25    Average accuracy: 96.48% Average recall: 4.99% 101.47
# Mult: 1.5 ***********************************************************
# Standard: Mult 1.5    Average accuracy: 98.32% Average recall: 0.00% 98.32
# Mult: 2 ***********************************************************
# Standard: Mult 2    Average accuracy: 98.32% Average recall: 0.00% 98.32
# Mult: 3 ***********************************************************
# Standard: Mult 3    Average accuracy: 98.32% Average recall: 0.00% 98.32
# Mult: 4 ***********************************************************
# Standard: Mult 4    Average accuracy: 98.32% Average recall: 0.00% 98.32
# Mult: 5 ***********************************************************
# Standard: Mult 5    Average accuracy: 98.32% Average recall: 0.00% 98.32
#
#  ___________________ With Thresholds ___________________
# Mult: 0 ***********************************************************
# Mult: 0 Thresh: 0.2  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0 Thresh: 0.3  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0 Thresh: 0.4  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0 Thresh: 0.46  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0 Thresh: 0.47  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0 Thresh: 0.48  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0 Thresh: 0.49  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0 Thresh: 0.5  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0 Thresh: 0.51  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0 Thresh: 0.52  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0 Thresh: 0.53  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0 Thresh: 0.54  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0 Thresh: 0.55  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0 Thresh: 0.6  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0 Thresh: 0.7  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0 Thresh: 0.95  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0 Thresh: 0.96  Acc: 98.14%   Recall: 0.66% = 98.80
# Mult: 0 Thresh: 0.97  Acc: 81.33%   Recall: 30.98% = 112.31
# Mult: 0 Thresh: 0.975  Acc: 59.55%   Recall: 43.70% = 103.25
# Mult: 0 Thresh: 0.985  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.5 ***********************************************************
# Mult: 0.5 Thresh: 0.2  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.5 Thresh: 0.3  Acc: 85.90%   Recall: 15.60% = 101.50
# Mult: 0.5 Thresh: 0.4  Acc: 1.76%   Recall: 100.00% = 101.76
# Mult: 0.5 Thresh: 0.46  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.5 Thresh: 0.47  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.5 Thresh: 0.48  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.5 Thresh: 0.49  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.5 Thresh: 0.5  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.5 Thresh: 0.51  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.5 Thresh: 0.52  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.5 Thresh: 0.53  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.5 Thresh: 0.54  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.5 Thresh: 0.55  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.5 Thresh: 0.6  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.5 Thresh: 0.7  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.5 Thresh: 0.95  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.5 Thresh: 0.96  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.5 Thresh: 0.97  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.5 Thresh: 0.975  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.5 Thresh: 0.985  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.75 ***********************************************************
# Mult: 0.75 Thresh: 0.2  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.75 Thresh: 0.3  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.75 Thresh: 0.4  Acc: 77.14%   Recall: 27.29% = 104.43
# Mult: 0.75 Thresh: 0.46  Acc: 22.41%   Recall: 98.82% = 121.24
# Mult: 0.75 Thresh: 0.47  Acc: 7.67%   Recall: 99.82% = 107.48
# Mult: 0.75 Thresh: 0.48  Acc: 3.28%   Recall: 99.99% = 103.27
# Mult: 0.75 Thresh: 0.49  Acc: 2.09%   Recall: 100.00% = 102.09
# Mult: 0.75 Thresh: 0.5  Acc: 1.75%   Recall: 100.00% = 101.75
# Mult: 0.75 Thresh: 0.51  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.75 Thresh: 0.52  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.75 Thresh: 0.53  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.75 Thresh: 0.54  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.75 Thresh: 0.55  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.75 Thresh: 0.6  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.75 Thresh: 0.7  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.75 Thresh: 0.95  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.75 Thresh: 0.96  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.75 Thresh: 0.97  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.75 Thresh: 0.975  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.75 Thresh: 0.985  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.85 ***********************************************************
# Mult: 0.85 Thresh: 0.2  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.85 Thresh: 0.3  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.85 Thresh: 0.4  Acc: 97.35%   Recall: 2.31% = 99.66
# Mult: 0.85 Thresh: 0.46  Acc: 50.41%   Recall: 75.18% = 125.58
# Mult: 0.85 Thresh: 0.47  Acc: 43.45%   Recall: 86.21% = 129.66
# Mult: 0.85 Thresh: 0.48  Acc: 34.67%   Recall: 93.80% = 128.47
# Mult: 0.85 Thresh: 0.49  Acc: 24.11%   Recall: 98.35% = 122.46
# Mult: 0.85 Thresh: 0.5  Acc: 9.12%   Recall: 99.78% = 108.91
# Mult: 0.85 Thresh: 0.51  Acc: 4.19%   Recall: 99.99% = 104.18
# Mult: 0.85 Thresh: 0.52  Acc: 2.12%   Recall: 100.00% = 102.12
# Mult: 0.85 Thresh: 0.53  Acc: 1.76%   Recall: 100.00% = 101.76
# Mult: 0.85 Thresh: 0.54  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.85 Thresh: 0.55  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.85 Thresh: 0.6  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.85 Thresh: 0.7  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.85 Thresh: 0.95  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.85 Thresh: 0.96  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.85 Thresh: 0.97  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.85 Thresh: 0.975  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.85 Thresh: 0.985  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.9 ***********************************************************
# Mult: 0.9 Thresh: 0.2  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.9 Thresh: 0.3  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.9 Thresh: 0.4  Acc: 98.27%   Recall: 0.00% = 98.27
# Mult: 0.9 Thresh: 0.46  Acc: 62.28%   Recall: 56.45% = 118.73
# Mult: 0.9 Thresh: 0.47  Acc: 53.67%   Recall: 73.07% = 126.74
# Mult: 0.9 Thresh: 0.48  Acc: 46.41%   Recall: 82.91% = 129.33
# Mult: 0.9 Thresh: 0.49  Acc: 39.57%   Recall: 90.94% = 130.51
# Mult: 0.9 Thresh: 0.5  Acc: 29.18%   Recall: 96.67% = 125.85
# Mult: 0.9 Thresh: 0.51  Acc: 15.11%   Recall: 99.55% = 114.66
# Mult: 0.9 Thresh: 0.52  Acc: 5.27%   Recall: 99.93% = 105.21
# Mult: 0.9 Thresh: 0.53  Acc: 2.68%   Recall: 100.00% = 102.68
# Mult: 0.9 Thresh: 0.54  Acc: 1.85%   Recall: 100.00% = 101.85
# Mult: 0.9 Thresh: 0.55  Acc: 1.69%   Recall: 100.00% = 101.69
# Mult: 0.9 Thresh: 0.6  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.9 Thresh: 0.7  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.9 Thresh: 0.95  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.9 Thresh: 0.96  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.9 Thresh: 0.97  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.9 Thresh: 0.975  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.9 Thresh: 0.985  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.95 ***********************************************************
# Mult: 0.95 Thresh: 0.2  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.95 Thresh: 0.3  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.95 Thresh: 0.4  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.95 Thresh: 0.46  Acc: 74.82%   Recall: 29.46% = 104.28
# Mult: 0.95 Thresh: 0.47  Acc: 65.15%   Recall: 49.59% = 114.74
# Mult: 0.95 Thresh: 0.48  Acc: 56.41%   Recall: 67.72% = 124.13
# Mult: 0.95 Thresh: 0.49  Acc: 48.77%   Recall: 76.47% = 125.24
# Mult: 0.95 Thresh: 0.5  Acc: 42.00%   Recall: 87.42% = 129.41
# Mult: 0.95 Thresh: 0.51  Acc: 32.28%   Recall: 94.79% = 127.07
# Mult: 0.95 Thresh: 0.52  Acc: 20.08%   Recall: 99.02% = 119.10
# Mult: 0.95 Thresh: 0.53  Acc: 7.40%   Recall: 99.87% = 107.27
# Mult: 0.95 Thresh: 0.54  Acc: 3.16%   Recall: 99.99% = 103.16
# Mult: 0.95 Thresh: 0.55  Acc: 2.04%   Recall: 100.00% = 102.04
# Mult: 0.95 Thresh: 0.6  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.95 Thresh: 0.7  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.95 Thresh: 0.95  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.95 Thresh: 0.96  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.95 Thresh: 0.97  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.95 Thresh: 0.975  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.95 Thresh: 0.985  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1 ***********************************************************
# Mult: 1 Thresh: 0.2  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 1 Thresh: 0.3  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 1 Thresh: 0.4  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 1 Thresh: 0.46  Acc: 88.34%   Recall: 13.83% = 102.17
# Mult: 1 Thresh: 0.47  Acc: 77.79%   Recall: 26.04% = 103.83
# Mult: 1 Thresh: 0.48  Acc: 67.32%   Recall: 43.88% = 111.20
# Mult: 1 Thresh: 0.49  Acc: 59.05%   Recall: 63.91% = 122.96
# Mult: 1 Thresh: 0.5  Acc: 50.86%   Recall: 74.96% = 125.83
# Mult: 1 Thresh: 0.51  Acc: 43.96%   Recall: 85.92% = 129.88
# Mult: 1 Thresh: 0.52  Acc: 35.11%   Recall: 93.36% = 128.47
# Mult: 1 Thresh: 0.53  Acc: 25.82%   Recall: 98.31% = 124.13
# Mult: 1 Thresh: 0.54  Acc: 9.72%   Recall: 99.78% = 109.50
# Mult: 1 Thresh: 0.55  Acc: 4.36%   Recall: 99.99% = 104.36
# Mult: 1 Thresh: 0.6  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1 Thresh: 0.7  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1 Thresh: 0.95  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1 Thresh: 0.96  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1 Thresh: 0.97  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1 Thresh: 0.975  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1 Thresh: 0.985  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.25 ***********************************************************
# Mult: 1.25 Thresh: 0.2  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 1.25 Thresh: 0.3  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 1.25 Thresh: 0.4  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 1.25 Thresh: 0.46  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 1.25 Thresh: 0.47  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 1.25 Thresh: 0.48  Acc: 98.26%   Recall: 0.00% = 98.26
# Mult: 1.25 Thresh: 0.49  Acc: 97.74%   Recall: 0.55% = 98.29
# Mult: 1.25 Thresh: 0.5  Acc: 96.48%   Recall: 4.99% = 101.47
# Mult: 1.25 Thresh: 0.51  Acc: 93.49%   Recall: 10.03% = 103.52
# Mult: 1.25 Thresh: 0.52  Acc: 82.47%   Recall: 17.80% = 100.26
# Mult: 1.25 Thresh: 0.53  Acc: 72.19%   Recall: 32.17% = 104.36
# Mult: 1.25 Thresh: 0.54  Acc: 63.83%   Recall: 52.22% = 116.06
# Mult: 1.25 Thresh: 0.55  Acc: 55.04%   Recall: 69.47% = 124.51
# Mult: 1.25 Thresh: 0.6  Acc: 6.65%   Recall: 99.91% = 106.56
# Mult: 1.25 Thresh: 0.7  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.25 Thresh: 0.95  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.25 Thresh: 0.96  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.25 Thresh: 0.97  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.25 Thresh: 0.975  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.25 Thresh: 0.985  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.5 ***********************************************************
# Mult: 1.5 Thresh: 0.2  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 1.5 Thresh: 0.3  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 1.5 Thresh: 0.4  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 1.5 Thresh: 0.46  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 1.5 Thresh: 0.47  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 1.5 Thresh: 0.48  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 1.5 Thresh: 0.49  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 1.5 Thresh: 0.5  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 1.5 Thresh: 0.51  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 1.5 Thresh: 0.52  Acc: 98.31%   Recall: 0.00% = 98.31
# Mult: 1.5 Thresh: 0.53  Acc: 98.11%   Recall: 0.03% = 98.14
# Mult: 1.5 Thresh: 0.54  Acc: 97.33%   Recall: 2.46% = 99.79
# Mult: 1.5 Thresh: 0.55  Acc: 95.44%   Recall: 7.73% = 103.17
# Mult: 1.5 Thresh: 0.6  Acc: 50.75%   Recall: 74.96% = 125.71
# Mult: 1.5 Thresh: 0.7  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.5 Thresh: 0.95  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.5 Thresh: 0.96  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.5 Thresh: 0.97  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.5 Thresh: 0.975  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.5 Thresh: 0.985  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 2 ***********************************************************
# Mult: 2 Thresh: 0.2  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 2 Thresh: 0.3  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 2 Thresh: 0.4  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 2 Thresh: 0.46  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 2 Thresh: 0.47  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 2 Thresh: 0.48  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 2 Thresh: 0.49  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 2 Thresh: 0.5  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 2 Thresh: 0.51  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 2 Thresh: 0.52  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 2 Thresh: 0.53  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 2 Thresh: 0.54  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 2 Thresh: 0.55  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 2 Thresh: 0.6  Acc: 98.17%   Recall: 0.02% = 98.19
# Mult: 2 Thresh: 0.7  Acc: 11.14%   Recall: 99.71% = 110.85
# Mult: 2 Thresh: 0.95  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 2 Thresh: 0.96  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 2 Thresh: 0.97  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 2 Thresh: 0.975  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 2 Thresh: 0.985  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 3 ***********************************************************
# Mult: 3 Thresh: 0.2  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 3 Thresh: 0.3  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 3 Thresh: 0.4  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 3 Thresh: 0.46  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 3 Thresh: 0.47  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 3 Thresh: 0.48  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 3 Thresh: 0.49  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 3 Thresh: 0.5  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 3 Thresh: 0.51  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 3 Thresh: 0.52  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 3 Thresh: 0.53  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 3 Thresh: 0.54  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 3 Thresh: 0.55  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 3 Thresh: 0.6  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 3 Thresh: 0.7  Acc: 97.56%   Recall: 0.78% = 98.35
# Mult: 3 Thresh: 0.95  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 3 Thresh: 0.96  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 3 Thresh: 0.97  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 3 Thresh: 0.975  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 3 Thresh: 0.985  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 4 ***********************************************************
# Mult: 4 Thresh: 0.2  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 4 Thresh: 0.3  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 4 Thresh: 0.4  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 4 Thresh: 0.46  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 4 Thresh: 0.47  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 4 Thresh: 0.48  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 4 Thresh: 0.49  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 4 Thresh: 0.5  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 4 Thresh: 0.51  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 4 Thresh: 0.52  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 4 Thresh: 0.53  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 4 Thresh: 0.54  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 4 Thresh: 0.55  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 4 Thresh: 0.6  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 4 Thresh: 0.7  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 4 Thresh: 0.95  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 4 Thresh: 0.96  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 4 Thresh: 0.97  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 4 Thresh: 0.975  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 4 Thresh: 0.985  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 5 ***********************************************************
# Mult: 5 Thresh: 0.2  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 5 Thresh: 0.3  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 5 Thresh: 0.4  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 5 Thresh: 0.46  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 5 Thresh: 0.47  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 5 Thresh: 0.48  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 5 Thresh: 0.49  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 5 Thresh: 0.5  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 5 Thresh: 0.51  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 5 Thresh: 0.52  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 5 Thresh: 0.53  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 5 Thresh: 0.54  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 5 Thresh: 0.55  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 5 Thresh: 0.6  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 5 Thresh: 0.7  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 5 Thresh: 0.95  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 5 Thresh: 0.96  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 5 Thresh: 0.97  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 5 Thresh: 0.975  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 5 Thresh: 0.985  Acc: 1.68%   Recall: 100.00% = 101.68

# %% [markdown]
# #### With Unsafe Class as Threshold

# %%
# Train the Multiomial Naive Bayes five times with the five batches.
for mult in mults:
    print(f"Mult: {mult} ***********************************************************")
    acc_total = 0
    rec_tot = 0
    acc_total_th = 0
    rec_tot_th = 0
    classifier = MultinomialNB() # Initiate classifier
    for b_num, batch in enumerate(batches):
        # Variable/Classification Split
        X = batch.drop(df.columns[[0, 1, 11]], axis=1) # Drop columns 0, 1 and 12 (index, episode, safe)
        Y = batch["Safe"]

        # Split into Train and test set
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=6)

        # Recombine X_train and Y_train for balancing
        X_train = X_train.copy() # To nullify Pandas view warning
        X_train["Safe"] = Y_train

        # Balance the data
        balanced_data = balance_samples(X_train, mult)

        # Split out data back into X_train and Y_train again
        Y_train = balanced_data["Safe"]
        X_train = balanced_data.drop("Safe", axis=1)

        # Train Classifier
        classifier.partial_fit(X_train, Y_train, classes=[0, 1])

        # Make predictions using classifier
        Y_pred = classifier.predict(X_test)
        accuracy = accuracy_score(Y_test, Y_pred)
        recall = recall_score(Y_test, Y_pred, pos_label=0)
        acc_total += accuracy
        rec_tot += recall

    print(f"Mult {mult} Average accuracy: {acc_total/5*100:.2f}% Average recall: {rec_tot/5*100:.2f}% = {(acc_total/5*100)+(rec_tot/5*100):.2f}")

print()
print(" ___________________ With Thresholds ___________________")
for mult in mults:
    print(f"Mult: {mult} ***********************************************************")
    for th in ths:
        acc_total = 0
        rec_tot = 0
        acc_total_th = 0
        rec_tot_th = 0
        classifier = MultinomialNB() # Initiate classifier
        for b_num, batch in enumerate(batches):
            # Variable/Classification Split
            X = batch.drop(df.columns[[0, 1, 11]], axis=1) # Drop columns 0, 1 and 12 (index, episode, safe)
            Y = batch["Safe"]

            # Split into Train and test set
            X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=6)

            # Recombine X_train and Y_train for balancing
            X_train = X_train.copy() # To nullify Pandas view warning
            X_train["Safe"] = Y_train

            # Balance the data
            balanced_data = balance_samples(X_train, mult)

            # Split out data back into X_train and Y_train again
            Y_train = balanced_data["Safe"]
            X_train = balanced_data.drop("Safe", axis=1)

            # Train Classifier
            classifier.partial_fit(X_train, Y_train, classes=[0, 1])

            # Make predictions using classifier
            Y_pred = classifier.predict(X_test)
            accuracy = accuracy_score(Y_test, Y_pred)
            recall = recall_score(Y_test, Y_pred, pos_label=0)
            #print(f"Standard: Unsafe Recall: {recall:.2f} Accuracy: {accuracy*100:.2f}%")
            acc_total += accuracy
            rec_tot += recall
            
            # Using a threshold for the safe class
            threshold = th
            Y_probs = classifier.predict_proba(X_test)
            Y_pred_custom = (Y_probs[:, 0] >= th).astype(int)
            accuracy = accuracy_score(Y_test, Y_pred_custom)
            recall = recall_score(Y_test, Y_pred_custom, pos_label=0)
            acc_total_th += accuracy
            rec_tot_th += recall
                            
        print(f"Mult: {mult} Thresh: {th}  Acc: {acc_total_th/5*100:.2f}%   Recall: {rec_tot_th/5*100:.2f}% = {(acc_total_th/5*100)+(rec_tot_th/5*100):.2f}")
# Out:
# Mult: 0 ***********************************************************
# Mult 0 Average accuracy: 98.32% Average recall: 0.00% = 98.32
# Mult: 0.5 ***********************************************************
# Mult 0.5 Average accuracy: 1.68% Average recall: 100.00% = 101.68
# Mult: 0.75 ***********************************************************
# Mult 0.75 Average accuracy: 1.75% Average recall: 100.00% = 101.75
# Mult: 0.85 ***********************************************************
# Mult 0.85 Average accuracy: 9.12% Average recall: 99.78% = 108.91
# Mult: 0.9 ***********************************************************
# Mult 0.9 Average accuracy: 29.18% Average recall: 96.67% = 125.85
# Mult: 0.95 ***********************************************************
# Mult 0.95 Average accuracy: 42.00% Average recall: 87.42% = 129.41
# Mult: 1 ***********************************************************
# Mult 1 Average accuracy: 50.86% Average recall: 74.96% = 125.83
# Mult: 1.25 ***********************************************************
# Mult 1.25 Average accuracy: 96.48% Average recall: 4.99% = 101.47
# Mult: 1.5 ***********************************************************
# Mult 1.5 Average accuracy: 98.32% Average recall: 0.00% = 98.32
# Mult: 2 ***********************************************************
# Mult 2 Average accuracy: 98.32% Average recall: 0.00% = 98.32
# Mult: 3 ***********************************************************
# Mult 3 Average accuracy: 98.32% Average recall: 0.00% = 98.32
# Mult: 4 ***********************************************************
# Mult 4 Average accuracy: 98.32% Average recall: 0.00% = 98.32
# Mult: 5 ***********************************************************
# Mult 5 Average accuracy: 98.32% Average recall: 0.00% = 98.32
#
#  ___________________ With Thresholds ___________________
# Mult: 0 ***********************************************************
# Mult: 0 Thresh: 0.2  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0 Thresh: 0.3  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0 Thresh: 0.4  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0 Thresh: 0.46  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0 Thresh: 0.47  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0 Thresh: 0.48  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0 Thresh: 0.49  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0 Thresh: 0.5  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0 Thresh: 0.51  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0 Thresh: 0.52  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0 Thresh: 0.53  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0 Thresh: 0.54  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0 Thresh: 0.55  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0 Thresh: 0.6  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0 Thresh: 0.7  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0 Thresh: 0.95  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0 Thresh: 0.96  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0 Thresh: 0.97  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0 Thresh: 0.975  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0 Thresh: 0.985  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.5 ***********************************************************
# Mult: 0.5 Thresh: 0.2  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.5 Thresh: 0.3  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.5 Thresh: 0.4  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.5 Thresh: 0.46  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.5 Thresh: 0.47  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.5 Thresh: 0.48  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.5 Thresh: 0.49  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.5 Thresh: 0.5  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.5 Thresh: 0.51  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.5 Thresh: 0.52  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.5 Thresh: 0.53  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.5 Thresh: 0.54  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.5 Thresh: 0.55  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.5 Thresh: 0.6  Acc: 98.24%   Recall: 0.00% = 98.24
# Mult: 0.5 Thresh: 0.7  Acc: 14.10%   Recall: 84.40% = 98.50
# Mult: 0.5 Thresh: 0.95  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.5 Thresh: 0.96  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.5 Thresh: 0.97  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.5 Thresh: 0.975  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.5 Thresh: 0.985  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.75 ***********************************************************
# Mult: 0.75 Thresh: 0.2  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.75 Thresh: 0.3  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.75 Thresh: 0.4  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.75 Thresh: 0.46  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.75 Thresh: 0.47  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.75 Thresh: 0.48  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.75 Thresh: 0.49  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.75 Thresh: 0.5  Acc: 98.25%   Recall: 0.00% = 98.25
# Mult: 0.75 Thresh: 0.51  Acc: 97.91%   Recall: 0.00% = 97.91
# Mult: 0.75 Thresh: 0.52  Acc: 96.72%   Recall: 0.01% = 96.73
# Mult: 0.75 Thresh: 0.53  Acc: 92.33%   Recall: 0.18% = 92.52
# Mult: 0.75 Thresh: 0.54  Acc: 77.59%   Recall: 1.18% = 78.76
# Mult: 0.75 Thresh: 0.55  Acc: 66.84%   Recall: 5.80% = 72.64
# Mult: 0.75 Thresh: 0.6  Acc: 22.86%   Recall: 72.71% = 95.57
# Mult: 0.75 Thresh: 0.7  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.75 Thresh: 0.95  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.75 Thresh: 0.96  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.75 Thresh: 0.97  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.75 Thresh: 0.975  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.75 Thresh: 0.985  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.85 ***********************************************************
# Mult: 0.85 Thresh: 0.2  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.85 Thresh: 0.3  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.85 Thresh: 0.4  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.85 Thresh: 0.46  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.85 Thresh: 0.47  Acc: 98.24%   Recall: 0.00% = 98.24
# Mult: 0.85 Thresh: 0.48  Acc: 97.88%   Recall: 0.00% = 97.88
# Mult: 0.85 Thresh: 0.49  Acc: 95.81%   Recall: 0.01% = 95.82
# Mult: 0.85 Thresh: 0.5  Acc: 90.88%   Recall: 0.22% = 91.09
# Mult: 0.85 Thresh: 0.51  Acc: 75.89%   Recall: 1.65% = 77.54
# Mult: 0.85 Thresh: 0.52  Acc: 65.33%   Recall: 6.20% = 71.53
# Mult: 0.85 Thresh: 0.53  Acc: 56.55%   Recall: 13.79% = 70.34
# Mult: 0.85 Thresh: 0.54  Acc: 49.59%   Recall: 24.82% = 74.42
# Mult: 0.85 Thresh: 0.55  Acc: 41.51%   Recall: 35.06% = 76.58
# Mult: 0.85 Thresh: 0.6  Acc: 2.65%   Recall: 97.69% = 100.34
# Mult: 0.85 Thresh: 0.7  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.85 Thresh: 0.95  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.85 Thresh: 0.96  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.85 Thresh: 0.97  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.85 Thresh: 0.975  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.85 Thresh: 0.985  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.9 ***********************************************************
# Mult: 0.9 Thresh: 0.2  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.9 Thresh: 0.3  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.9 Thresh: 0.4  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.9 Thresh: 0.46  Acc: 98.15%   Recall: 0.00% = 98.15
# Mult: 0.9 Thresh: 0.47  Acc: 97.32%   Recall: 0.00% = 97.32
# Mult: 0.9 Thresh: 0.48  Acc: 94.73%   Recall: 0.07% = 94.79
# Mult: 0.9 Thresh: 0.49  Acc: 84.89%   Recall: 0.45% = 85.34
# Mult: 0.9 Thresh: 0.5  Acc: 70.82%   Recall: 3.33% = 74.15
# Mult: 0.9 Thresh: 0.51  Acc: 60.43%   Recall: 9.06% = 69.49
# Mult: 0.9 Thresh: 0.52  Acc: 53.59%   Recall: 17.09% = 70.67
# Mult: 0.9 Thresh: 0.53  Acc: 46.33%   Recall: 26.93% = 73.26
# Mult: 0.9 Thresh: 0.54  Acc: 37.72%   Recall: 43.55% = 81.27
# Mult: 0.9 Thresh: 0.55  Acc: 29.32%   Recall: 63.96% = 93.28
# Mult: 0.9 Thresh: 0.6  Acc: 1.73%   Recall: 100.00% = 101.73
# Mult: 0.9 Thresh: 0.7  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.9 Thresh: 0.95  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.9 Thresh: 0.96  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.9 Thresh: 0.97  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.9 Thresh: 0.975  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.9 Thresh: 0.985  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.95 ***********************************************************
# Mult: 0.95 Thresh: 0.2  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.95 Thresh: 0.3  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.95 Thresh: 0.4  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 0.95 Thresh: 0.46  Acc: 96.84%   Recall: 0.01% = 96.84
# Mult: 0.95 Thresh: 0.47  Acc: 92.60%   Recall: 0.13% = 92.73
# Mult: 0.95 Thresh: 0.48  Acc: 79.92%   Recall: 0.98% = 80.90
# Mult: 0.95 Thresh: 0.49  Acc: 67.72%   Recall: 5.21% = 72.93
# Mult: 0.95 Thresh: 0.5  Acc: 58.00%   Recall: 12.58% = 70.59
# Mult: 0.95 Thresh: 0.51  Acc: 51.23%   Recall: 23.53% = 74.76
# Mult: 0.95 Thresh: 0.52  Acc: 43.59%   Recall: 32.28% = 75.87
# Mult: 0.95 Thresh: 0.53  Acc: 34.85%   Recall: 50.41% = 85.26
# Mult: 0.95 Thresh: 0.54  Acc: 25.18%   Recall: 70.54% = 95.72
# Mult: 0.95 Thresh: 0.55  Acc: 14.99%   Recall: 83.79% = 98.78
# Mult: 0.95 Thresh: 0.6  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.95 Thresh: 0.7  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.95 Thresh: 0.95  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.95 Thresh: 0.96  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.95 Thresh: 0.97  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.95 Thresh: 0.975  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 0.95 Thresh: 0.985  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1 ***********************************************************
# Mult: 1 Thresh: 0.2  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 1 Thresh: 0.3  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 1 Thresh: 0.4  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 1 Thresh: 0.46  Acc: 90.28%   Recall: 0.22% = 90.50
# Mult: 1 Thresh: 0.47  Acc: 74.18%   Recall: 1.69% = 75.87
# Mult: 1 Thresh: 0.48  Acc: 64.89%   Recall: 6.64% = 71.53
# Mult: 1 Thresh: 0.49  Acc: 56.04%   Recall: 14.08% = 70.12
# Mult: 1 Thresh: 0.5  Acc: 49.14%   Recall: 25.04% = 74.17
# Mult: 1 Thresh: 0.51  Acc: 40.95%   Recall: 36.09% = 77.04
# Mult: 1 Thresh: 0.52  Acc: 32.68%   Recall: 56.12% = 88.80
# Mult: 1 Thresh: 0.53  Acc: 22.21%   Recall: 73.96% = 96.17
# Mult: 1 Thresh: 0.54  Acc: 11.66%   Recall: 86.17% = 97.83
# Mult: 1 Thresh: 0.55  Acc: 4.66%   Recall: 92.11% = 96.77
# Mult: 1 Thresh: 0.6  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1 Thresh: 0.7  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1 Thresh: 0.95  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1 Thresh: 0.96  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1 Thresh: 0.97  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1 Thresh: 0.975  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1 Thresh: 0.985  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.25 ***********************************************************
# Mult: 1.25 Thresh: 0.2  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 1.25 Thresh: 0.3  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 1.25 Thresh: 0.4  Acc: 93.35%   Recall: 0.09% = 93.44
# Mult: 1.25 Thresh: 0.46  Acc: 36.17%   Recall: 47.78% = 83.94
# Mult: 1.25 Thresh: 0.47  Acc: 27.81%   Recall: 67.83% = 95.64
# Mult: 1.25 Thresh: 0.48  Acc: 17.53%   Recall: 82.20% = 99.74
# Mult: 1.25 Thresh: 0.49  Acc: 6.51%   Recall: 89.97% = 96.48
# Mult: 1.25 Thresh: 0.5  Acc: 3.52%   Recall: 95.01% = 98.53
# Mult: 1.25 Thresh: 0.51  Acc: 2.26%   Recall: 99.45% = 101.71
# Mult: 1.25 Thresh: 0.52  Acc: 1.74%   Recall: 100.00% = 101.74
# Mult: 1.25 Thresh: 0.53  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.25 Thresh: 0.54  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.25 Thresh: 0.55  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.25 Thresh: 0.6  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.25 Thresh: 0.7  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.25 Thresh: 0.95  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.25 Thresh: 0.96  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.25 Thresh: 0.97  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.25 Thresh: 0.975  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.25 Thresh: 0.985  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.5 ***********************************************************
# Mult: 1.5 Thresh: 0.2  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 1.5 Thresh: 0.3  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 1.5 Thresh: 0.4  Acc: 49.25%   Recall: 25.04% = 74.29
# Mult: 1.5 Thresh: 0.46  Acc: 2.67%   Recall: 97.54% = 100.21
# Mult: 1.5 Thresh: 0.47  Acc: 1.89%   Recall: 99.97% = 101.86
# Mult: 1.5 Thresh: 0.48  Acc: 1.69%   Recall: 100.00% = 101.69
# Mult: 1.5 Thresh: 0.49  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.5 Thresh: 0.5  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.5 Thresh: 0.51  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.5 Thresh: 0.52  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.5 Thresh: 0.53  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.5 Thresh: 0.54  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.5 Thresh: 0.55  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.5 Thresh: 0.6  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.5 Thresh: 0.7  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.5 Thresh: 0.95  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.5 Thresh: 0.96  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.5 Thresh: 0.97  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.5 Thresh: 0.975  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 1.5 Thresh: 0.985  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 2 ***********************************************************
# Mult: 2 Thresh: 0.2  Acc: 98.32%   Recall: 0.00% = 98.32
# Mult: 2 Thresh: 0.3  Acc: 88.86%   Recall: 0.29% = 89.15
# Mult: 2 Thresh: 0.4  Acc: 1.83%   Recall: 99.98% = 101.81
# Mult: 2 Thresh: 0.46  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 2 Thresh: 0.47  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 2 Thresh: 0.48  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 2 Thresh: 0.49  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 2 Thresh: 0.5  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 2 Thresh: 0.51  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 2 Thresh: 0.52  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 2 Thresh: 0.53  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 2 Thresh: 0.54  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 2 Thresh: 0.55  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 2 Thresh: 0.6  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 2 Thresh: 0.7  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 2 Thresh: 0.95  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 2 Thresh: 0.96  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 2 Thresh: 0.97  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 2 Thresh: 0.975  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 2 Thresh: 0.985  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 3 ***********************************************************
# Mult: 3 Thresh: 0.2  Acc: 98.27%   Recall: 0.00% = 98.27
# Mult: 3 Thresh: 0.3  Acc: 2.44%   Recall: 99.22% = 101.65
# Mult: 3 Thresh: 0.4  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 3 Thresh: 0.46  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 3 Thresh: 0.47  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 3 Thresh: 0.48  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 3 Thresh: 0.49  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 3 Thresh: 0.5  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 3 Thresh: 0.51  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 3 Thresh: 0.52  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 3 Thresh: 0.53  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 3 Thresh: 0.54  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 3 Thresh: 0.55  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 3 Thresh: 0.6  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 3 Thresh: 0.7  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 3 Thresh: 0.95  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 3 Thresh: 0.96  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 3 Thresh: 0.97  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 3 Thresh: 0.975  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 3 Thresh: 0.985  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 4 ***********************************************************
# Mult: 4 Thresh: 0.2  Acc: 49.32%   Recall: 25.11% = 74.43
# Mult: 4 Thresh: 0.3  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 4 Thresh: 0.4  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 4 Thresh: 0.46  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 4 Thresh: 0.47  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 4 Thresh: 0.48  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 4 Thresh: 0.49  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 4 Thresh: 0.5  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 4 Thresh: 0.51  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 4 Thresh: 0.52  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 4 Thresh: 0.53  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 4 Thresh: 0.54  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 4 Thresh: 0.55  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 4 Thresh: 0.6  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 4 Thresh: 0.7  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 4 Thresh: 0.95  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 4 Thresh: 0.96  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 4 Thresh: 0.97  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 4 Thresh: 0.975  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 4 Thresh: 0.985  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 5 ***********************************************************
# Mult: 5 Thresh: 0.2  Acc: 3.33%   Recall: 95.14% = 98.47
# Mult: 5 Thresh: 0.3  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 5 Thresh: 0.4  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 5 Thresh: 0.46  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 5 Thresh: 0.47  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 5 Thresh: 0.48  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 5 Thresh: 0.49  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 5 Thresh: 0.5  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 5 Thresh: 0.51  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 5 Thresh: 0.52  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 5 Thresh: 0.53  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 5 Thresh: 0.54  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 5 Thresh: 0.55  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 5 Thresh: 0.6  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 5 Thresh: 0.7  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 5 Thresh: 0.95  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 5 Thresh: 0.96  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 5 Thresh: 0.97  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 5 Thresh: 0.975  Acc: 1.68%   Recall: 100.00% = 101.68
# Mult: 5 Thresh: 0.985  Acc: 1.68%   Recall: 100.00% = 101.68

# %% [markdown]
# #### Gaussian Naive Bayes

# %%
# Train the Gaussian Naive Bayes five times with the five batches.
for mult in mults:
    print(f"Mult: {mult} ***********************************************************")
    acc_total = 0
    rec_tot = 0
    acc_total_th = 0
    rec_tot_th = 0
    classifier = GaussianNB() # Initiate classifier
    for b_num, batch in enumerate(batches):
        # Variable/Classification Split
        X = batch.drop(df.columns[[0, 1, 11]], axis=1) # Drop columns 0, 1 and 12 (index, episode, safe)
        Y = batch["Safe"]

        # Split into Train and test set
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=6)

        # Recombine X_train and Y_train for balancing
        X_train = X_train.copy() # To nullify Pandas view warning
        X_train["Safe"] = Y_train

        # Balance the data
        balanced_data = balance_samples(X_train, mult)

        # Split out data back into X_train and Y_train again
        Y_train = balanced_data["Safe"]
        X_train = balanced_data.drop("Safe", axis=1)

        # Train Classifier
        classifier.partial_fit(X_train, Y_train, classes=[0, 1])

        # Make predictions using classifier
        Y_pred = classifier.predict(X_test)
        accuracy = accuracy_score(Y_test, Y_pred)
        recall = recall_score(Y_test, Y_pred, pos_label=0)
        acc_total += accuracy
        rec_tot += recall

    print(f"Mult {mult}  Average accuracy: {acc_total/5*100:.2f}% Average recall: {rec_tot/5*100:.2f}%  = {(acc_total/5*100)+(rec_tot/5*100):.2f}")

print()
print(" ___________________ With Thresholds ___________________")
for mult in mults:
    print(f"Mult: {mult} ***********************************************************")
    for th in ths:
        acc_total = 0
        rec_tot = 0
        acc_total_th = 0
        rec_tot_th = 0
        classifier = GaussianNB() # Initiate classifier
        for b_num, batch in enumerate(batches):
            # Variable/Classification Split
            X = batch.drop(df.columns[[0, 1, 11]], axis=1) # Drop columns 0, 1 and 12 (index, episode, safe)
            Y = batch["Safe"]

            # Split into Train and test set
            X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=6)

            # Recombine X_train and Y_train for balancing
            X_train = X_train.copy() # To nullify Pandas view warning
            X_train["Safe"] = Y_train

            # Balance the data
            balanced_data = balance_samples(X_train, mult)

            # Split out data back into X_train and Y_train again
            Y_train = balanced_data["Safe"]
            X_train = balanced_data.drop("Safe", axis=1)

            # Train Classifier
            classifier.partial_fit(X_train, Y_train, classes=[0, 1])

            # Make predictions using classifier
            Y_pred = classifier.predict(X_test)
            accuracy = accuracy_score(Y_test, Y_pred)
            recall = recall_score(Y_test, Y_pred, pos_label=0)
            acc_total += accuracy
            rec_tot += recall
            
            # Using a threshold for the safe class
            threshold = th
            Y_probs = classifier.predict_proba(X_test)
            Y_pred_custom = (Y_probs[:, 1] >= th).astype(int)
            accuracy = accuracy_score(Y_test, Y_pred_custom)
            recall = recall_score(Y_test, Y_pred_custom, pos_label=0)
            acc_total_th += accuracy
            rec_tot_th += recall
            
        print(f"Mult: {mult} Thresh: {th}  Acc: {acc_total_th/5*100:.2f}% Average recall: {rec_tot_th/5*100:.2f}% = {(acc_total_th/5*100)+(rec_tot_th/5*100):.2f}")
# Out:
# Mult: 0 ***********************************************************
# Mult 0  Average accuracy: 98.32% Average recall: 0.00%  = 98.32
# Mult: 0.5 ***********************************************************
# Mult 0.5  Average accuracy: 38.95% Average recall: 94.91%  = 133.87
# Mult: 0.75 ***********************************************************
# Mult 0.75  Average accuracy: 46.78% Average recall: 85.14%  = 131.92
# Mult: 0.85 ***********************************************************
# Mult 0.85  Average accuracy: 49.26% Average recall: 81.98%  = 131.24
# Mult: 0.9 ***********************************************************
# Mult 0.9  Average accuracy: 50.42% Average recall: 80.55%  = 130.97
# Mult: 0.95 ***********************************************************
# Mult 0.95  Average accuracy: 51.96% Average recall: 79.43%  = 131.40
# Mult: 1 ***********************************************************
# Mult 1  Average accuracy: 53.12% Average recall: 77.65%  = 130.77
# Mult: 1.25 ***********************************************************
# Mult 1.25  Average accuracy: 59.30% Average recall: 70.63%  = 129.92
# Mult: 1.5 ***********************************************************
# Mult 1.5  Average accuracy: 64.90% Average recall: 61.08%  = 125.98
# Mult: 2 ***********************************************************
# Mult 2  Average accuracy: 73.18% Average recall: 46.31%  = 119.49
# Mult: 3 ***********************************************************
# Mult 3  Average accuracy: 79.39% Average recall: 28.31%  = 107.71
# Mult: 4 ***********************************************************
# Mult 4  Average accuracy: 84.20% Average recall: 18.29%  = 102.49
# Mult: 5 ***********************************************************
# Mult 5  Average accuracy: 87.74% Average recall: 12.62%  = 100.36
#
#  ___________________ With Thresholds ___________________
# Mult: 0 ***********************************************************
# Mult: 0 Thresh: 0.2  Acc: 98.32% Average recall: 0.00% = 98.32
# Mult: 0 Thresh: 0.3  Acc: 98.32% Average recall: 0.00% = 98.32
# Mult: 0 Thresh: 0.4  Acc: 98.32% Average recall: 0.00% = 98.32
# Mult: 0 Thresh: 0.46  Acc: 98.32% Average recall: 0.00% = 98.32
# Mult: 0 Thresh: 0.47  Acc: 98.32% Average recall: 0.00% = 98.32
# Mult: 0 Thresh: 0.48  Acc: 98.32% Average recall: 0.00% = 98.32
# Mult: 0 Thresh: 0.49  Acc: 98.32% Average recall: 0.00% = 98.32
# Mult: 0 Thresh: 0.5  Acc: 98.32% Average recall: 0.00% = 98.32
# Mult: 0 Thresh: 0.51  Acc: 98.32% Average recall: 0.00% = 98.32
# Mult: 0 Thresh: 0.52  Acc: 98.32% Average recall: 0.00% = 98.32
# Mult: 0 Thresh: 0.53  Acc: 98.32% Average recall: 0.00% = 98.32
# Mult: 0 Thresh: 0.54  Acc: 98.32% Average recall: 0.00% = 98.32
# Mult: 0 Thresh: 0.55  Acc: 98.32% Average recall: 0.00% = 98.32
# Mult: 0 Thresh: 0.6  Acc: 98.32% Average recall: 0.00% = 98.32
# Mult: 0 Thresh: 0.7  Acc: 98.23% Average recall: 0.09% = 98.32
# Mult: 0 Thresh: 0.95  Acc: 80.65% Average recall: 28.31% = 108.96
# Mult: 0 Thresh: 0.96  Acc: 74.90% Average recall: 39.21% = 114.11
# Mult: 0 Thresh: 0.97  Acc: 66.16% Average recall: 59.14% = 125.30
# Mult: 0 Thresh: 0.975  Acc: 60.05% Average recall: 68.04% = 128.09
# Mult: 0 Thresh: 0.985  Acc: 45.99% Average recall: 88.02% = 134.01
# Mult: 0.5 ***********************************************************
# Mult: 0.5 Thresh: 0.2  Acc: 72.81% Average recall: 46.38% = 119.19
# Mult: 0.5 Thresh: 0.3  Acc: 57.01% Average recall: 73.84% = 130.86
# Mult: 0.5 Thresh: 0.4  Acc: 46.37% Average recall: 85.56% = 131.93
# Mult: 0.5 Thresh: 0.46  Acc: 41.55% Average recall: 91.45% = 133.00
# Mult: 0.5 Thresh: 0.47  Acc: 40.68% Average recall: 92.49% = 133.17
# Mult: 0.5 Thresh: 0.48  Acc: 40.16% Average recall: 93.77% = 133.92
# Mult: 0.5 Thresh: 0.49  Acc: 39.32% Average recall: 94.24% = 133.56
# Mult: 0.5 Thresh: 0.5  Acc: 38.95% Average recall: 94.91% = 133.87
# Mult: 0.5 Thresh: 0.51  Acc: 38.23% Average recall: 95.98% = 134.21
# Mult: 0.5 Thresh: 0.52  Acc: 37.68% Average recall: 96.56% = 134.25
# Mult: 0.5 Thresh: 0.53  Acc: 37.27% Average recall: 96.96% = 134.23
# Mult: 0.5 Thresh: 0.54  Acc: 36.77% Average recall: 97.27% = 134.04
# Mult: 0.5 Thresh: 0.55  Acc: 36.25% Average recall: 97.96% = 134.21
# Mult: 0.5 Thresh: 0.6  Acc: 30.01% Average recall: 98.77% = 128.78
# Mult: 0.5 Thresh: 0.7  Acc: 11.23% Average recall: 99.33% = 110.56
# Mult: 0.5 Thresh: 0.95  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 0.5 Thresh: 0.96  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 0.5 Thresh: 0.97  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 0.5 Thresh: 0.975  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 0.5 Thresh: 0.985  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 0.75 ***********************************************************
# Mult: 0.75 Thresh: 0.2  Acc: 79.42% Average recall: 28.33% = 107.75
# Mult: 0.75 Thresh: 0.3  Acc: 69.98% Average recall: 52.65% = 122.64
# Mult: 0.75 Thresh: 0.4  Acc: 56.61% Average recall: 74.17% = 130.78
# Mult: 0.75 Thresh: 0.46  Acc: 50.16% Average recall: 81.07% = 131.22
# Mult: 0.75 Thresh: 0.47  Acc: 49.26% Average recall: 81.99% = 131.24
# Mult: 0.75 Thresh: 0.48  Acc: 48.50% Average recall: 82.77% = 131.28
# Mult: 0.75 Thresh: 0.49  Acc: 47.70% Average recall: 84.06% = 131.76
# Mult: 0.75 Thresh: 0.5  Acc: 46.78% Average recall: 85.14% = 131.92
# Mult: 0.75 Thresh: 0.51  Acc: 45.92% Average recall: 85.52% = 131.43
# Mult: 0.75 Thresh: 0.52  Acc: 45.20% Average recall: 86.60% = 131.81
# Mult: 0.75 Thresh: 0.53  Acc: 44.24% Average recall: 87.78% = 132.01
# Mult: 0.75 Thresh: 0.54  Acc: 43.43% Average recall: 88.47% = 131.90
# Mult: 0.75 Thresh: 0.55  Acc: 42.70% Average recall: 90.22% = 132.92
# Mult: 0.75 Thresh: 0.6  Acc: 39.16% Average recall: 94.41% = 133.57
# Mult: 0.75 Thresh: 0.7  Acc: 25.99% Average recall: 98.82% = 124.81
# Mult: 0.75 Thresh: 0.95  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 0.75 Thresh: 0.96  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 0.75 Thresh: 0.97  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 0.75 Thresh: 0.975  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 0.75 Thresh: 0.985  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 0.85 ***********************************************************
# Mult: 0.85 Thresh: 0.2  Acc: 81.23% Average recall: 26.29% = 107.52
# Mult: 0.85 Thresh: 0.3  Acc: 73.07% Average recall: 46.52% = 119.59
# Mult: 0.85 Thresh: 0.4  Acc: 60.01% Average recall: 69.49% = 129.50
# Mult: 0.85 Thresh: 0.46  Acc: 53.00% Average recall: 77.95% = 130.95
# Mult: 0.85 Thresh: 0.47  Acc: 52.09% Average recall: 78.78% = 130.87
# Mult: 0.85 Thresh: 0.48  Acc: 51.04% Average recall: 80.06% = 131.09
# Mult: 0.85 Thresh: 0.49  Acc: 50.14% Average recall: 80.97% = 131.11
# Mult: 0.85 Thresh: 0.5  Acc: 49.26% Average recall: 81.98% = 131.24
# Mult: 0.85 Thresh: 0.51  Acc: 48.52% Average recall: 82.77% = 131.29
# Mult: 0.85 Thresh: 0.52  Acc: 47.66% Average recall: 83.87% = 131.53
# Mult: 0.85 Thresh: 0.53  Acc: 46.80% Average recall: 84.89% = 131.69
# Mult: 0.85 Thresh: 0.54  Acc: 45.93% Average recall: 85.50% = 131.43
# Mult: 0.85 Thresh: 0.55  Acc: 45.17% Average recall: 86.54% = 131.71
# Mult: 0.85 Thresh: 0.6  Acc: 41.23% Average recall: 91.56% = 132.79
# Mult: 0.85 Thresh: 0.7  Acc: 33.13% Average recall: 98.45% = 131.58
# Mult: 0.85 Thresh: 0.95  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 0.85 Thresh: 0.96  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 0.85 Thresh: 0.97  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 0.85 Thresh: 0.975  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 0.85 Thresh: 0.985  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 0.9 ***********************************************************
# Mult: 0.9 Thresh: 0.2  Acc: 82.25% Average recall: 24.09% = 106.34
# Mult: 0.9 Thresh: 0.3  Acc: 74.41% Average recall: 44.34% = 118.75
# Mult: 0.9 Thresh: 0.4  Acc: 61.76% Average recall: 66.81% = 128.57
# Mult: 0.9 Thresh: 0.46  Acc: 54.47% Average recall: 76.36% = 130.83
# Mult: 0.9 Thresh: 0.47  Acc: 53.61% Average recall: 77.37% = 130.97
# Mult: 0.9 Thresh: 0.48  Acc: 52.47% Average recall: 78.54% = 131.01
# Mult: 0.9 Thresh: 0.49  Acc: 51.59% Average recall: 79.57% = 131.16
# Mult: 0.9 Thresh: 0.5  Acc: 50.42% Average recall: 80.55% = 130.97
# Mult: 0.9 Thresh: 0.51  Acc: 49.59% Average recall: 81.62% = 131.21
# Mult: 0.9 Thresh: 0.52  Acc: 48.90% Average recall: 82.49% = 131.38
# Mult: 0.9 Thresh: 0.53  Acc: 48.04% Average recall: 83.01% = 131.04
# Mult: 0.9 Thresh: 0.54  Acc: 47.19% Average recall: 84.65% = 131.84
# Mult: 0.9 Thresh: 0.55  Acc: 46.24% Average recall: 85.32% = 131.56
# Mult: 0.9 Thresh: 0.6  Acc: 42.13% Average recall: 90.65% = 132.78
# Mult: 0.9 Thresh: 0.7  Acc: 35.08% Average recall: 98.18% = 133.26
# Mult: 0.9 Thresh: 0.95  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 0.9 Thresh: 0.96  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 0.9 Thresh: 0.97  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 0.9 Thresh: 0.975  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 0.9 Thresh: 0.985  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 0.95 ***********************************************************
# Mult: 0.95 Thresh: 0.2  Acc: 83.16% Average recall: 19.93% = 103.09
# Mult: 0.95 Thresh: 0.3  Acc: 75.39% Average recall: 41.92% = 117.31
# Mult: 0.95 Thresh: 0.4  Acc: 63.52% Average recall: 63.36% = 126.89
# Mult: 0.95 Thresh: 0.46  Acc: 56.11% Average recall: 74.39% = 130.51
# Mult: 0.95 Thresh: 0.47  Acc: 54.97% Average recall: 75.80% = 130.78
# Mult: 0.95 Thresh: 0.48  Acc: 53.98% Average recall: 77.23% = 131.21
# Mult: 0.95 Thresh: 0.49  Acc: 52.74% Average recall: 78.22% = 130.97
# Mult: 0.95 Thresh: 0.5  Acc: 51.96% Average recall: 79.43% = 131.40
# Mult: 0.95 Thresh: 0.51  Acc: 50.83% Average recall: 80.05% = 130.88
# Mult: 0.95 Thresh: 0.52  Acc: 50.02% Average recall: 81.34% = 131.36
# Mult: 0.95 Thresh: 0.53  Acc: 49.22% Average recall: 82.17% = 131.39
# Mult: 0.95 Thresh: 0.54  Acc: 48.34% Average recall: 82.90% = 131.24
# Mult: 0.95 Thresh: 0.55  Acc: 47.59% Average recall: 84.12% = 131.72
# Mult: 0.95 Thresh: 0.6  Acc: 43.09% Average recall: 88.79% = 131.88
# Mult: 0.95 Thresh: 0.7  Acc: 36.14% Average recall: 97.48% = 133.62
# Mult: 0.95 Thresh: 0.95  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 0.95 Thresh: 0.96  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 0.95 Thresh: 0.97  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 0.95 Thresh: 0.975  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 0.95 Thresh: 0.985  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 1 ***********************************************************
# Mult: 1 Thresh: 0.2  Acc: 84.22% Average recall: 18.57% = 102.79
# Mult: 1 Thresh: 0.3  Acc: 76.29% Average recall: 38.65% = 114.94
# Mult: 1 Thresh: 0.4  Acc: 65.31% Average recall: 60.29% = 125.59
# Mult: 1 Thresh: 0.46  Acc: 57.62% Average recall: 72.74% = 130.36
# Mult: 1 Thresh: 0.47  Acc: 56.38% Average recall: 74.18% = 130.56
# Mult: 1 Thresh: 0.48  Acc: 55.22% Average recall: 75.36% = 130.58
# Mult: 1 Thresh: 0.49  Acc: 54.20% Average recall: 76.92% = 131.12
# Mult: 1 Thresh: 0.5  Acc: 53.12% Average recall: 77.65% = 130.77
# Mult: 1 Thresh: 0.51  Acc: 52.25% Average recall: 79.01% = 131.26
# Mult: 1 Thresh: 0.52  Acc: 51.13% Average recall: 79.65% = 130.78
# Mult: 1 Thresh: 0.53  Acc: 50.23% Average recall: 80.98% = 131.20
# Mult: 1 Thresh: 0.54  Acc: 49.38% Average recall: 81.98% = 131.36
# Mult: 1 Thresh: 0.55  Acc: 48.53% Average recall: 82.77% = 131.30
# Mult: 1 Thresh: 0.6  Acc: 44.21% Average recall: 87.81% = 132.02
# Mult: 1 Thresh: 0.7  Acc: 36.92% Average recall: 97.05% = 133.96
# Mult: 1 Thresh: 0.95  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 1 Thresh: 0.96  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 1 Thresh: 0.97  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 1 Thresh: 0.975  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 1 Thresh: 0.985  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 1.25 ***********************************************************
# Mult: 1.25 Thresh: 0.2  Acc: 87.58% Average recall: 12.60% = 100.18
# Mult: 1.25 Thresh: 0.3  Acc: 79.08% Average recall: 28.83% = 107.90
# Mult: 1.25 Thresh: 0.4  Acc: 71.45% Average recall: 49.03% = 120.48
# Mult: 1.25 Thresh: 0.46  Acc: 64.29% Average recall: 61.80% = 126.09
# Mult: 1.25 Thresh: 0.47  Acc: 62.98% Average recall: 64.58% = 127.56
# Mult: 1.25 Thresh: 0.48  Acc: 61.72% Average recall: 66.92% = 128.65
# Mult: 1.25 Thresh: 0.49  Acc: 60.56% Average recall: 68.82% = 129.38
# Mult: 1.25 Thresh: 0.5  Acc: 59.30% Average recall: 70.63% = 129.92
# Mult: 1.25 Thresh: 0.51  Acc: 57.97% Average recall: 71.94% = 129.92
# Mult: 1.25 Thresh: 0.52  Acc: 57.01% Average recall: 73.41% = 130.42
# Mult: 1.25 Thresh: 0.53  Acc: 55.83% Average recall: 74.74% = 130.57
# Mult: 1.25 Thresh: 0.54  Acc: 54.51% Average recall: 76.13% = 130.64
# Mult: 1.25 Thresh: 0.55  Acc: 53.66% Average recall: 77.33% = 130.99
# Mult: 1.25 Thresh: 0.6  Acc: 48.81% Average recall: 82.62% = 131.43
# Mult: 1.25 Thresh: 0.7  Acc: 40.19% Average recall: 93.63% = 133.82
# Mult: 1.25 Thresh: 0.95  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 1.25 Thresh: 0.96  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 1.25 Thresh: 0.97  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 1.25 Thresh: 0.975  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 1.25 Thresh: 0.985  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 1.5 ***********************************************************
# Mult: 1.5 Thresh: 0.2  Acc: 90.71% Average recall: 9.40% = 100.11
# Mult: 1.5 Thresh: 0.3  Acc: 81.71% Average recall: 24.37% = 106.08
# Mult: 1.5 Thresh: 0.4  Acc: 75.47% Average recall: 41.62% = 117.09
# Mult: 1.5 Thresh: 0.46  Acc: 69.72% Average recall: 52.81% = 122.54
# Mult: 1.5 Thresh: 0.47  Acc: 68.47% Average recall: 54.26% = 122.73
# Mult: 1.5 Thresh: 0.48  Acc: 67.22% Average recall: 56.32% = 123.54
# Mult: 1.5 Thresh: 0.49  Acc: 66.03% Average recall: 58.30% = 124.32
# Mult: 1.5 Thresh: 0.5  Acc: 64.90% Average recall: 61.08% = 125.98
# Mult: 1.5 Thresh: 0.51  Acc: 63.45% Average recall: 62.98% = 126.43
# Mult: 1.5 Thresh: 0.52  Acc: 62.29% Average recall: 66.00% = 128.29
# Mult: 1.5 Thresh: 0.53  Acc: 61.01% Average recall: 68.36% = 129.37
# Mult: 1.5 Thresh: 0.54  Acc: 59.90% Average recall: 69.60% = 129.51
# Mult: 1.5 Thresh: 0.55  Acc: 58.53% Average recall: 71.38% = 129.91
# Mult: 1.5 Thresh: 0.6  Acc: 52.84% Average recall: 78.03% = 130.87
# Mult: 1.5 Thresh: 0.7  Acc: 43.48% Average recall: 88.67% = 132.15
# Mult: 1.5 Thresh: 0.95  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 1.5 Thresh: 0.96  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 1.5 Thresh: 0.97  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 1.5 Thresh: 0.975  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 1.5 Thresh: 0.985  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 2 ***********************************************************
# Mult: 2 Thresh: 0.2  Acc: 96.00% Average recall: 1.51% = 97.51
# Mult: 2 Thresh: 0.3  Acc: 86.69% Average recall: 14.52% = 101.21
# Mult: 2 Thresh: 0.4  Acc: 79.48% Average recall: 28.45% = 107.93
# Mult: 2 Thresh: 0.46  Acc: 76.26% Average recall: 40.28% = 116.54
# Mult: 2 Thresh: 0.47  Acc: 75.58% Average recall: 41.37% = 116.96
# Mult: 2 Thresh: 0.48  Acc: 74.81% Average recall: 43.48% = 118.28
# Mult: 2 Thresh: 0.49  Acc: 74.03% Average recall: 45.02% = 119.04
# Mult: 2 Thresh: 0.5  Acc: 73.18% Average recall: 46.31% = 119.49
# Mult: 2 Thresh: 0.51  Acc: 71.98% Average recall: 48.06% = 120.04
# Mult: 2 Thresh: 0.52  Acc: 71.15% Average recall: 50.38% = 121.53
# Mult: 2 Thresh: 0.53  Acc: 69.91% Average recall: 52.41% = 122.32
# Mult: 2 Thresh: 0.54  Acc: 68.89% Average recall: 53.93% = 122.82
# Mult: 2 Thresh: 0.55  Acc: 67.52% Average recall: 56.07% = 123.59
# Mult: 2 Thresh: 0.6  Acc: 61.11% Average recall: 67.97% = 129.08
# Mult: 2 Thresh: 0.7  Acc: 49.43% Average recall: 82.13% = 131.57
# Mult: 2 Thresh: 0.95  Acc: 1.74% Average recall: 100.00% = 101.74
# Mult: 2 Thresh: 0.96  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 2 Thresh: 0.97  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 2 Thresh: 0.975  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 2 Thresh: 0.985  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 3 ***********************************************************
# Mult: 3 Thresh: 0.2  Acc: 98.04% Average recall: 0.16% = 98.20
# Mult: 3 Thresh: 0.3  Acc: 93.96% Average recall: 4.48% = 98.44
# Mult: 3 Thresh: 0.4  Acc: 86.15% Average recall: 15.67% = 101.82
# Mult: 3 Thresh: 0.46  Acc: 81.81% Average recall: 24.12% = 105.93
# Mult: 3 Thresh: 0.47  Acc: 81.10% Average recall: 25.96% = 107.05
# Mult: 3 Thresh: 0.48  Acc: 80.55% Average recall: 27.13% = 107.68
# Mult: 3 Thresh: 0.49  Acc: 79.88% Average recall: 27.61% = 107.49
# Mult: 3 Thresh: 0.5  Acc: 79.39% Average recall: 28.31% = 107.71
# Mult: 3 Thresh: 0.51  Acc: 78.92% Average recall: 29.68% = 108.60
# Mult: 3 Thresh: 0.52  Acc: 78.44% Average recall: 31.71% = 110.15
# Mult: 3 Thresh: 0.53  Acc: 77.93% Average recall: 33.53% = 111.46
# Mult: 3 Thresh: 0.54  Acc: 77.46% Average recall: 35.79% = 113.26
# Mult: 3 Thresh: 0.55  Acc: 76.93% Average recall: 38.06% = 114.99
# Mult: 3 Thresh: 0.6  Acc: 72.98% Average recall: 46.37% = 119.35
# Mult: 3 Thresh: 0.7  Acc: 60.07% Average recall: 69.67% = 129.74
# Mult: 3 Thresh: 0.95  Acc: 4.21% Average recall: 99.90% = 104.11
# Mult: 3 Thresh: 0.96  Acc: 2.33% Average recall: 100.00% = 102.33
# Mult: 3 Thresh: 0.97  Acc: 1.69% Average recall: 100.00% = 101.69
# Mult: 3 Thresh: 0.975  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 3 Thresh: 0.985  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 4 ***********************************************************
# Mult: 4 Thresh: 0.2  Acc: 98.29% Average recall: 0.03% = 98.32
# Mult: 4 Thresh: 0.3  Acc: 97.22% Average recall: 0.30% = 97.53
# Mult: 4 Thresh: 0.4  Acc: 90.94% Average recall: 8.68% = 99.63
# Mult: 4 Thresh: 0.46  Acc: 86.75% Average recall: 14.25% = 101.00
# Mult: 4 Thresh: 0.47  Acc: 86.20% Average recall: 15.57% = 101.78
# Mult: 4 Thresh: 0.48  Acc: 85.50% Average recall: 16.06% = 101.56
# Mult: 4 Thresh: 0.49  Acc: 84.98% Average recall: 17.25% = 102.23
# Mult: 4 Thresh: 0.5  Acc: 84.20% Average recall: 18.29% = 102.49
# Mult: 4 Thresh: 0.51  Acc: 83.30% Average recall: 19.79% = 103.09
# Mult: 4 Thresh: 0.52  Acc: 82.70% Average recall: 21.89% = 104.59
# Mult: 4 Thresh: 0.53  Acc: 81.93% Average recall: 24.06% = 105.99
# Mult: 4 Thresh: 0.54  Acc: 81.25% Average recall: 25.95% = 107.20
# Mult: 4 Thresh: 0.55  Acc: 80.65% Average recall: 27.08% = 107.73
# Mult: 4 Thresh: 0.6  Acc: 77.98% Average recall: 33.30% = 111.28
# Mult: 4 Thresh: 0.7  Acc: 68.83% Average recall: 53.96% = 122.79
# Mult: 4 Thresh: 0.95  Acc: 10.06% Average recall: 99.36% = 109.42
# Mult: 4 Thresh: 0.96  Acc: 4.72% Average recall: 99.69% = 104.41
# Mult: 4 Thresh: 0.97  Acc: 2.21% Average recall: 100.00% = 102.21
# Mult: 4 Thresh: 0.975  Acc: 1.72% Average recall: 100.00% = 101.72
# Mult: 4 Thresh: 0.985  Acc: 1.68% Average recall: 100.00% = 101.68
# Mult: 5 ***********************************************************
# Mult: 5 Thresh: 0.2  Acc: 98.32% Average recall: 0.00% = 98.32
# Mult: 5 Thresh: 0.3  Acc: 98.00% Average recall: 0.18% = 98.18
# Mult: 5 Thresh: 0.4  Acc: 95.21% Average recall: 2.25% = 97.47
# Mult: 5 Thresh: 0.46  Acc: 90.56% Average recall: 9.34% = 99.90
# Mult: 5 Thresh: 0.47  Acc: 89.77% Average recall: 9.84% = 99.60
# Mult: 5 Thresh: 0.48  Acc: 89.02% Average recall: 10.75% = 99.77
# Mult: 5 Thresh: 0.49  Acc: 88.46% Average recall: 11.22% = 99.68
# Mult: 5 Thresh: 0.5  Acc: 87.74% Average recall: 12.62% = 100.36
# Mult: 5 Thresh: 0.51  Acc: 87.15% Average recall: 13.78% = 100.93
# Mult: 5 Thresh: 0.52  Acc: 86.55% Average recall: 14.74% = 101.29
# Mult: 5 Thresh: 0.53  Acc: 86.05% Average recall: 15.76% = 101.81
# Mult: 5 Thresh: 0.54  Acc: 85.30% Average recall: 16.52% = 101.82
# Mult: 5 Thresh: 0.55  Acc: 84.69% Average recall: 17.81% = 102.50
# Mult: 5 Thresh: 0.6  Acc: 80.94% Average recall: 26.35% = 107.29
# Mult: 5 Thresh: 0.7  Acc: 74.46% Average recall: 43.88% = 118.34
# Mult: 5 Thresh: 0.95  Acc: 17.64% Average recall: 99.07% = 116.71
# Mult: 5 Thresh: 0.96  Acc: 9.99% Average recall: 99.36% = 109.34
# Mult: 5 Thresh: 0.97  Acc: 3.99% Average recall: 99.90% = 103.90
# Mult: 5 Thresh: 0.975  Acc: 2.44% Average recall: 100.00% = 102.44
# Mult: 5 Thresh: 0.985  Acc: 1.68% Average recall: 100.00% = 101.68

# %% [markdown]
# #### With Unsafe Class as Threshold

# %%
# Train the Gaussian Naive Bayes five times with the five batches.
for mult in mults:
    print(f"Mult: {mult} ***********************************************************")
    acc_total = 0
    rec_tot = 0
    acc_total_th = 0
    rec_tot_th = 0
    classifier = GaussianNB() # Initiate classifier
    for b_num, batch in enumerate(batches):
        # Variable/Classification Split
        X = batch.drop(df.columns[[0, 1, 11]], axis=1) # Drop columns 0, 1 and 12 (index, episode, safe)
        Y = batch["Safe"]

        # Split into Train and test set
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=6)

        # Recombine X_train and Y_train for balancing
        X_train = X_train.copy() # To nullify Pandas view warning
        X_train["Safe"] = Y_train

        # Balance the data
        balanced_data = balance_samples(X_train, mult)

        # Split out data back into X_train and Y_train again
        Y_train = balanced_data["Safe"]
        X_train = balanced_data.drop("Safe", axis=1)

        # Train Classifier
        classifier.partial_fit(X_train, Y_train, classes=[0, 1])

        # Make predictions using classifier
        Y_pred = classifier.predict(X_test)
        accuracy = accuracy_score(Y_test, Y_pred)
        recall = recall_score(Y_test, Y_pred, pos_label=0)
        acc_total += accuracy
        rec_tot += recall

    print(f"Mult {mult} Average accuracy: {acc_total/5*100:.2f}% Average recall: {rec_tot/5*100:.2f}%  = {(acc_total/5*100)+(rec_tot/5*100):.2f}")

print()
print(" ___________________ With Thresholds ___________________")
for mult in mults:
    print(f"Mult: {mult} ***********************************************************")
    for th in ths:
        acc_total = 0
        rec_tot = 0
        acc_total_th = 0
        rec_tot_th = 0
        classifier = GaussianNB() # Initiate classifier
        for b_num, batch in enumerate(batches):
            # Variable/Classification Split
            X = batch.drop(df.columns[[0, 1, 11]], axis=1) # Drop columns 0, 1 and 12 (index, episode, safe)
            Y = batch["Safe"]

            # Split into Train and test set
            X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=6)

            # Recombine X_train and Y_train for balancing
            X_train = X_train.copy() # To nullify Pandas view warning
            X_train["Safe"] = Y_train

            # Balance the data
            balanced_data = balance_samples(X_train, mult)

            # Split out data back into X_train and Y_train again
            Y_train = balanced_data["Safe"]
            X_train = balanced_data.drop("Safe", axis=1)

            # Train Classifier
            classifier.partial_fit(X_train, Y_train, classes=[0, 1])

            # Make predictions using classifier
            Y_pred = classifier.predict(X_test)
            accuracy = accuracy_score(Y_test, Y_pred)
            recall = recall_score(Y_test, Y_pred, pos_label=0)
            acc_total += accuracy
            rec_tot += recall
            
            # Using a threshold for the safe class
            threshold = th
            Y_probs = classifier.predict_proba(X_test)
            Y_pred_custom = (Y_probs[:, 0] >= th).astype(int)
            accuracy = accuracy_score(Y_test, Y_pred_custom)
            recall = recall_score(Y_test, Y_pred_custom, pos_label=0)
            acc_total_th += accuracy
            rec_tot_th += recall
            
        print(f"Mult: {mult} Thresh: {th}  Acc: {acc_total_th/5*100:.2f}% Average recall: {rec_tot_th/5*100:.2f}% =  = {(acc_total_th/5*100)+(rec_tot_th/5*100):.2f}")
# Out:
# Mult: 0 ***********************************************************
# Mult 0 Average accuracy: 98.32% Average recall: 0.00%  = 98.32
# Mult: 0.5 ***********************************************************
# Mult 0.5 Average accuracy: 38.95% Average recall: 94.91%  = 133.87
# Mult: 0.75 ***********************************************************
# Mult 0.75 Average accuracy: 46.78% Average recall: 85.14%  = 131.92
# Mult: 0.85 ***********************************************************
# Mult 0.85 Average accuracy: 49.26% Average recall: 81.98%  = 131.24
# Mult: 0.9 ***********************************************************
# Mult 0.9 Average accuracy: 50.42% Average recall: 80.55%  = 130.97
# Mult: 0.95 ***********************************************************
# Mult 0.95 Average accuracy: 51.96% Average recall: 79.43%  = 131.40
# Mult: 1 ***********************************************************
# Mult 1 Average accuracy: 53.12% Average recall: 77.65%  = 130.77
# Mult: 1.25 ***********************************************************
# Mult 1.25 Average accuracy: 59.30% Average recall: 70.63%  = 129.92
# Mult: 1.5 ***********************************************************
# Mult 1.5 Average accuracy: 64.90% Average recall: 61.08%  = 125.98
# Mult: 2 ***********************************************************
# Mult 2 Average accuracy: 73.18% Average recall: 46.31%  = 119.49
# Mult: 3 ***********************************************************
# Mult 3 Average accuracy: 79.39% Average recall: 28.31%  = 107.71
# Mult: 4 ***********************************************************
# Mult 4 Average accuracy: 84.20% Average recall: 18.29%  = 102.49
# Mult: 5 ***********************************************************
# Mult 5 Average accuracy: 87.74% Average recall: 12.62%  = 100.36
#
#  ___________________ With Thresholds ___________________
# Mult: 0 ***********************************************************
# Mult: 0 Thresh: 0.2  Acc: 2.40% Average recall: 99.53% =  = 101.92
# Mult: 0 Thresh: 0.3  Acc: 1.77% Average recall: 99.91% =  = 101.68
# Mult: 0 Thresh: 0.4  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0 Thresh: 0.46  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0 Thresh: 0.47  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0 Thresh: 0.48  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0 Thresh: 0.49  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0 Thresh: 0.5  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0 Thresh: 0.51  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0 Thresh: 0.52  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0 Thresh: 0.53  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0 Thresh: 0.54  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0 Thresh: 0.55  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0 Thresh: 0.6  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0 Thresh: 0.7  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0 Thresh: 0.95  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0 Thresh: 0.96  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0 Thresh: 0.97  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0 Thresh: 0.975  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0 Thresh: 0.985  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0.5 ***********************************************************
# Mult: 0.5 Thresh: 0.2  Acc: 97.76% Average recall: 0.00% =  = 97.76
# Mult: 0.5 Thresh: 0.3  Acc: 88.77% Average recall: 0.67% =  = 89.44
# Mult: 0.5 Thresh: 0.4  Acc: 69.99% Average recall: 1.23% =  = 71.22
# Mult: 0.5 Thresh: 0.46  Acc: 63.23% Average recall: 2.73% =  = 65.96
# Mult: 0.5 Thresh: 0.47  Acc: 62.73% Average recall: 3.04% =  = 65.77
# Mult: 0.5 Thresh: 0.48  Acc: 62.32% Average recall: 3.44% =  = 65.75
# Mult: 0.5 Thresh: 0.49  Acc: 61.77% Average recall: 4.02% =  = 65.79
# Mult: 0.5 Thresh: 0.5  Acc: 61.05% Average recall: 5.09% =  = 66.13
# Mult: 0.5 Thresh: 0.51  Acc: 60.68% Average recall: 5.76% =  = 66.44
# Mult: 0.5 Thresh: 0.52  Acc: 59.84% Average recall: 6.23% =  = 66.08
# Mult: 0.5 Thresh: 0.53  Acc: 59.32% Average recall: 7.51% =  = 66.83
# Mult: 0.5 Thresh: 0.54  Acc: 58.45% Average recall: 8.55% =  = 67.00
# Mult: 0.5 Thresh: 0.55  Acc: 57.81% Average recall: 9.50% =  = 67.31
# Mult: 0.5 Thresh: 0.6  Acc: 53.63% Average recall: 14.44% =  = 68.07
# Mult: 0.5 Thresh: 0.7  Acc: 42.99% Average recall: 26.16% =  = 69.14
# Mult: 0.5 Thresh: 0.95  Acc: 2.74% Average recall: 99.73% =  = 102.48
# Mult: 0.5 Thresh: 0.96  Acc: 1.96% Average recall: 99.91% =  = 101.87
# Mult: 0.5 Thresh: 0.97  Acc: 1.70% Average recall: 99.97% =  = 101.66
# Mult: 0.5 Thresh: 0.975  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0.5 Thresh: 0.985  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0.75 ***********************************************************
# Mult: 0.75 Thresh: 0.2  Acc: 93.52% Average recall: 0.52% =  = 94.04
# Mult: 0.75 Thresh: 0.3  Acc: 74.01% Average recall: 1.18% =  = 75.19
# Mult: 0.75 Thresh: 0.4  Acc: 60.84% Average recall: 5.59% =  = 66.43
# Mult: 0.75 Thresh: 0.46  Acc: 56.57% Average recall: 11.53% =  = 68.10
# Mult: 0.75 Thresh: 0.47  Acc: 55.76% Average recall: 12.22% =  = 67.99
# Mult: 0.75 Thresh: 0.48  Acc: 54.80% Average recall: 13.40% =  = 68.19
# Mult: 0.75 Thresh: 0.49  Acc: 54.08% Average recall: 14.48% =  = 68.57
# Mult: 0.75 Thresh: 0.5  Acc: 53.22% Average recall: 14.86% =  = 68.08
# Mult: 0.75 Thresh: 0.51  Acc: 52.30% Average recall: 15.94% =  = 68.24
# Mult: 0.75 Thresh: 0.52  Acc: 51.50% Average recall: 17.23% =  = 68.72
# Mult: 0.75 Thresh: 0.53  Acc: 50.74% Average recall: 18.01% =  = 68.76
# Mult: 0.75 Thresh: 0.54  Acc: 49.84% Average recall: 18.93% =  = 68.78
# Mult: 0.75 Thresh: 0.55  Acc: 48.90% Average recall: 19.87% =  = 68.78
# Mult: 0.75 Thresh: 0.6  Acc: 43.39% Average recall: 25.83% =  = 69.22
# Mult: 0.75 Thresh: 0.7  Acc: 30.02% Average recall: 47.35% =  = 77.36
# Mult: 0.75 Thresh: 0.95  Acc: 1.74% Average recall: 99.92% =  = 101.66
# Mult: 0.75 Thresh: 0.96  Acc: 1.69% Average recall: 100.00% =  = 101.68
# Mult: 0.75 Thresh: 0.97  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0.75 Thresh: 0.975  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0.75 Thresh: 0.985  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0.85 ***********************************************************
# Mult: 0.85 Thresh: 0.2  Acc: 89.08% Average recall: 0.72% =  = 89.80
# Mult: 0.85 Thresh: 0.3  Acc: 66.87% Average recall: 1.55% =  = 68.42
# Mult: 0.85 Thresh: 0.4  Acc: 58.77% Average recall: 8.44% =  = 67.21
# Mult: 0.85 Thresh: 0.46  Acc: 54.07% Average recall: 14.50% =  = 68.57
# Mult: 0.85 Thresh: 0.47  Acc: 53.20% Average recall: 15.11% =  = 68.31
# Mult: 0.85 Thresh: 0.48  Acc: 52.34% Average recall: 16.13% =  = 68.47
# Mult: 0.85 Thresh: 0.49  Acc: 51.48% Average recall: 17.23% =  = 68.71
# Mult: 0.85 Thresh: 0.5  Acc: 50.74% Average recall: 18.02% =  = 68.76
# Mult: 0.85 Thresh: 0.51  Acc: 49.86% Average recall: 19.03% =  = 68.89
# Mult: 0.85 Thresh: 0.52  Acc: 48.96% Average recall: 19.94% =  = 68.91
# Mult: 0.85 Thresh: 0.53  Acc: 47.91% Average recall: 21.22% =  = 69.13
# Mult: 0.85 Thresh: 0.54  Acc: 47.00% Average recall: 22.05% =  = 69.05
# Mult: 0.85 Thresh: 0.55  Acc: 45.92% Average recall: 23.09% =  = 69.01
# Mult: 0.85 Thresh: 0.6  Acc: 39.99% Average recall: 30.51% =  = 70.50
# Mult: 0.85 Thresh: 0.7  Acc: 26.93% Average recall: 53.48% =  = 80.41
# Mult: 0.85 Thresh: 0.95  Acc: 1.70% Average recall: 99.97% =  = 101.66
# Mult: 0.85 Thresh: 0.96  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0.85 Thresh: 0.97  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0.85 Thresh: 0.975  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0.85 Thresh: 0.985  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0.9 ***********************************************************
# Mult: 0.9 Thresh: 0.2  Acc: 87.71% Average recall: 0.75% =  = 88.46
# Mult: 0.9 Thresh: 0.3  Acc: 64.92% Average recall: 1.82% =  = 66.74
# Mult: 0.9 Thresh: 0.4  Acc: 57.87% Average recall: 9.35% =  = 67.22
# Mult: 0.9 Thresh: 0.46  Acc: 52.81% Average recall: 15.35% =  = 68.16
# Mult: 0.9 Thresh: 0.47  Acc: 51.96% Average recall: 16.99% =  = 68.96
# Mult: 0.9 Thresh: 0.48  Acc: 51.10% Average recall: 17.51% =  = 68.62
# Mult: 0.9 Thresh: 0.49  Acc: 50.41% Average recall: 18.38% =  = 68.79
# Mult: 0.9 Thresh: 0.5  Acc: 49.58% Average recall: 19.45% =  = 69.03
# Mult: 0.9 Thresh: 0.51  Acc: 48.41% Average recall: 20.43% =  = 68.84
# Mult: 0.9 Thresh: 0.52  Acc: 47.53% Average recall: 21.46% =  = 68.99
# Mult: 0.9 Thresh: 0.53  Acc: 46.39% Average recall: 22.63% =  = 69.03
# Mult: 0.9 Thresh: 0.54  Acc: 45.53% Average recall: 23.64% =  = 69.17
# Mult: 0.9 Thresh: 0.55  Acc: 44.21% Average recall: 25.11% =  = 69.32
# Mult: 0.9 Thresh: 0.6  Acc: 38.24% Average recall: 33.19% =  = 71.43
# Mult: 0.9 Thresh: 0.7  Acc: 25.59% Average recall: 55.66% =  = 81.25
# Mult: 0.9 Thresh: 0.95  Acc: 1.69% Average recall: 100.00% =  = 101.68
# Mult: 0.9 Thresh: 0.96  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0.9 Thresh: 0.97  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0.9 Thresh: 0.975  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0.9 Thresh: 0.985  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0.95 ***********************************************************
# Mult: 0.95 Thresh: 0.2  Acc: 86.14% Average recall: 0.80% =  = 86.94
# Mult: 0.95 Thresh: 0.3  Acc: 63.86% Average recall: 2.52% =  = 66.38
# Mult: 0.95 Thresh: 0.4  Acc: 56.91% Average recall: 11.21% =  = 68.12
# Mult: 0.95 Thresh: 0.46  Acc: 51.66% Average recall: 17.10% =  = 68.76
# Mult: 0.95 Thresh: 0.47  Acc: 50.78% Average recall: 17.83% =  = 68.61
# Mult: 0.95 Thresh: 0.48  Acc: 49.98% Average recall: 18.66% =  = 68.64
# Mult: 0.95 Thresh: 0.49  Acc: 49.17% Average recall: 19.95% =  = 69.12
# Mult: 0.95 Thresh: 0.5  Acc: 48.04% Average recall: 20.57% =  = 68.60
# Mult: 0.95 Thresh: 0.51  Acc: 47.26% Average recall: 21.78% =  = 69.03
# Mult: 0.95 Thresh: 0.52  Acc: 46.02% Average recall: 22.77% =  = 68.79
# Mult: 0.95 Thresh: 0.53  Acc: 45.03% Average recall: 24.20% =  = 69.22
# Mult: 0.95 Thresh: 0.54  Acc: 43.89% Average recall: 25.61% =  = 69.49
# Mult: 0.95 Thresh: 0.55  Acc: 42.66% Average recall: 26.95% =  = 69.61
# Mult: 0.95 Thresh: 0.6  Acc: 36.48% Average recall: 36.64% =  = 73.11
# Mult: 0.95 Thresh: 0.7  Acc: 24.61% Average recall: 58.08% =  = 82.69
# Mult: 0.95 Thresh: 0.95  Acc: 1.69% Average recall: 100.00% =  = 101.68
# Mult: 0.95 Thresh: 0.96  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0.95 Thresh: 0.97  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0.95 Thresh: 0.975  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 0.95 Thresh: 0.985  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 1 ***********************************************************
# Mult: 1 Thresh: 0.2  Acc: 83.81% Average recall: 0.80% =  = 84.61
# Mult: 1 Thresh: 0.3  Acc: 63.08% Average recall: 2.95% =  = 66.04
# Mult: 1 Thresh: 0.4  Acc: 55.79% Average recall: 12.19% =  = 67.98
# Mult: 1 Thresh: 0.46  Acc: 50.62% Average recall: 18.02% =  = 68.64
# Mult: 1 Thresh: 0.47  Acc: 49.77% Average recall: 19.02% =  = 68.80
# Mult: 1 Thresh: 0.48  Acc: 48.87% Average recall: 20.35% =  = 69.22
# Mult: 1 Thresh: 0.49  Acc: 47.75% Average recall: 20.99% =  = 68.74
# Mult: 1 Thresh: 0.5  Acc: 46.88% Average recall: 22.35% =  = 69.23
# Mult: 1 Thresh: 0.51  Acc: 45.80% Average recall: 23.08% =  = 68.88
# Mult: 1 Thresh: 0.52  Acc: 44.78% Average recall: 24.64% =  = 69.42
# Mult: 1 Thresh: 0.53  Acc: 43.62% Average recall: 25.82% =  = 69.44
# Mult: 1 Thresh: 0.54  Acc: 42.38% Average recall: 27.26% =  = 69.64
# Mult: 1 Thresh: 0.55  Acc: 41.29% Average recall: 28.86% =  = 70.15
# Mult: 1 Thresh: 0.6  Acc: 34.69% Average recall: 39.71% =  = 74.41
# Mult: 1 Thresh: 0.7  Acc: 23.71% Average recall: 61.35% =  = 85.06
# Mult: 1 Thresh: 0.95  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 1 Thresh: 0.96  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 1 Thresh: 0.97  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 1 Thresh: 0.975  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 1 Thresh: 0.985  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 1.25 ***********************************************************
# Mult: 1.25 Thresh: 0.2  Acc: 74.96% Average recall: 1.14% =  = 76.09
# Mult: 1.25 Thresh: 0.3  Acc: 59.81% Average recall: 6.37% =  = 66.18
# Mult: 1.25 Thresh: 0.4  Acc: 51.19% Average recall: 17.38% =  = 68.57
# Mult: 1.25 Thresh: 0.46  Acc: 45.49% Average recall: 23.87% =  = 69.36
# Mult: 1.25 Thresh: 0.47  Acc: 44.17% Average recall: 25.26% =  = 69.43
# Mult: 1.25 Thresh: 0.48  Acc: 42.99% Average recall: 26.59% =  = 69.58
# Mult: 1.25 Thresh: 0.49  Acc: 42.03% Average recall: 28.06% =  = 70.08
# Mult: 1.25 Thresh: 0.5  Acc: 40.70% Average recall: 29.37% =  = 70.08
# Mult: 1.25 Thresh: 0.51  Acc: 39.44% Average recall: 31.18% =  = 70.62
# Mult: 1.25 Thresh: 0.52  Acc: 38.28% Average recall: 33.08% =  = 71.35
# Mult: 1.25 Thresh: 0.53  Acc: 37.02% Average recall: 35.42% =  = 72.44
# Mult: 1.25 Thresh: 0.54  Acc: 35.71% Average recall: 38.20% =  = 73.91
# Mult: 1.25 Thresh: 0.55  Acc: 34.45% Average recall: 40.48% =  = 74.93
# Mult: 1.25 Thresh: 0.6  Acc: 28.55% Average recall: 50.97% =  = 79.52
# Mult: 1.25 Thresh: 0.7  Acc: 20.92% Average recall: 71.17% =  = 92.10
# Mult: 1.25 Thresh: 0.95  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 1.25 Thresh: 0.96  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 1.25 Thresh: 0.97  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 1.25 Thresh: 0.975  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 1.25 Thresh: 0.985  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 1.5 ***********************************************************
# Mult: 1.5 Thresh: 0.2  Acc: 65.80% Average recall: 1.55% =  = 67.35
# Mult: 1.5 Thresh: 0.3  Acc: 56.52% Average recall: 11.33% =  = 67.85
# Mult: 1.5 Thresh: 0.4  Acc: 47.16% Average recall: 21.97% =  = 69.13
# Mult: 1.5 Thresh: 0.46  Acc: 40.10% Average recall: 30.40% =  = 70.49
# Mult: 1.5 Thresh: 0.47  Acc: 38.99% Average recall: 31.64% =  = 70.63
# Mult: 1.5 Thresh: 0.48  Acc: 37.71% Average recall: 34.00% =  = 71.71
# Mult: 1.5 Thresh: 0.49  Acc: 36.55% Average recall: 37.02% =  = 73.57
# Mult: 1.5 Thresh: 0.5  Acc: 35.10% Average recall: 38.92% =  = 74.02
# Mult: 1.5 Thresh: 0.51  Acc: 33.97% Average recall: 41.70% =  = 75.68
# Mult: 1.5 Thresh: 0.52  Acc: 32.78% Average recall: 43.68% =  = 76.46
# Mult: 1.5 Thresh: 0.53  Acc: 31.53% Average recall: 45.74% =  = 77.27
# Mult: 1.5 Thresh: 0.54  Acc: 30.28% Average recall: 47.19% =  = 77.46
# Mult: 1.5 Thresh: 0.55  Acc: 29.19% Average recall: 49.18% =  = 78.37
# Mult: 1.5 Thresh: 0.6  Acc: 24.53% Average recall: 58.38% =  = 82.91
# Mult: 1.5 Thresh: 0.7  Acc: 18.29% Average recall: 75.63% =  = 93.92
# Mult: 1.5 Thresh: 0.95  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 1.5 Thresh: 0.96  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 1.5 Thresh: 0.97  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 1.5 Thresh: 0.975  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 1.5 Thresh: 0.985  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 2 ***********************************************************
# Mult: 2 Thresh: 0.2  Acc: 60.93% Average recall: 5.32% =  = 66.25
# Mult: 2 Thresh: 0.3  Acc: 50.57% Average recall: 17.87% =  = 68.43
# Mult: 2 Thresh: 0.4  Acc: 38.89% Average recall: 32.03% =  = 70.92
# Mult: 2 Thresh: 0.46  Acc: 31.11% Average recall: 46.07% =  = 77.18
# Mult: 2 Thresh: 0.47  Acc: 30.09% Average recall: 47.59% =  = 77.68
# Mult: 2 Thresh: 0.48  Acc: 28.85% Average recall: 49.62% =  = 78.47
# Mult: 2 Thresh: 0.49  Acc: 28.02% Average recall: 51.94% =  = 79.96
# Mult: 2 Thresh: 0.5  Acc: 26.82% Average recall: 53.69% =  = 80.51
# Mult: 2 Thresh: 0.51  Acc: 25.97% Average recall: 54.98% =  = 80.96
# Mult: 2 Thresh: 0.52  Acc: 25.19% Average recall: 56.52% =  = 81.72
# Mult: 2 Thresh: 0.53  Acc: 24.42% Average recall: 58.63% =  = 83.04
# Mult: 2 Thresh: 0.54  Acc: 23.74% Average recall: 59.72% =  = 83.46
# Mult: 2 Thresh: 0.55  Acc: 23.03% Average recall: 62.39% =  = 85.42
# Mult: 2 Thresh: 0.6  Acc: 20.52% Average recall: 71.55% =  = 92.07
# Mult: 2 Thresh: 0.7  Acc: 13.31% Average recall: 85.48% =  = 98.79
# Mult: 2 Thresh: 0.95  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 2 Thresh: 0.96  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 2 Thresh: 0.97  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 2 Thresh: 0.975  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 2 Thresh: 0.985  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 3 ***********************************************************
# Mult: 3 Thresh: 0.2  Acc: 53.31% Average recall: 14.66% =  = 67.97
# Mult: 3 Thresh: 0.3  Acc: 39.93% Average recall: 30.33% =  = 70.26
# Mult: 3 Thresh: 0.4  Acc: 27.02% Average recall: 53.63% =  = 80.65
# Mult: 3 Thresh: 0.46  Acc: 22.54% Average recall: 64.21% =  = 86.74
# Mult: 3 Thresh: 0.47  Acc: 22.07% Average recall: 66.47% =  = 88.54
# Mult: 3 Thresh: 0.48  Acc: 21.56% Average recall: 68.29% =  = 89.85
# Mult: 3 Thresh: 0.49  Acc: 21.08% Average recall: 70.32% =  = 91.40
# Mult: 3 Thresh: 0.5  Acc: 20.61% Average recall: 71.69% =  = 92.29
# Mult: 3 Thresh: 0.51  Acc: 20.12% Average recall: 72.39% =  = 92.51
# Mult: 3 Thresh: 0.52  Acc: 19.45% Average recall: 72.87% =  = 92.32
# Mult: 3 Thresh: 0.53  Acc: 18.90% Average recall: 74.04% =  = 92.95
# Mult: 3 Thresh: 0.54  Acc: 18.19% Average recall: 75.88% =  = 94.07
# Mult: 3 Thresh: 0.55  Acc: 17.58% Average recall: 77.58% =  = 95.16
# Mult: 3 Thresh: 0.6  Acc: 13.85% Average recall: 84.33% =  = 98.18
# Mult: 3 Thresh: 0.7  Acc: 6.04% Average recall: 95.52% =  = 101.56
# Mult: 3 Thresh: 0.95  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 3 Thresh: 0.96  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 3 Thresh: 0.97  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 3 Thresh: 0.975  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 3 Thresh: 0.985  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 4 ***********************************************************
# Mult: 4 Thresh: 0.2  Acc: 47.16% Average recall: 21.82% =  = 68.98
# Mult: 4 Thresh: 0.3  Acc: 31.17% Average recall: 46.04% =  = 77.21
# Mult: 4 Thresh: 0.4  Acc: 22.02% Average recall: 66.70% =  = 88.72
# Mult: 4 Thresh: 0.46  Acc: 18.75% Average recall: 74.05% =  = 92.80
# Mult: 4 Thresh: 0.47  Acc: 18.07% Average recall: 75.94% =  = 94.01
# Mult: 4 Thresh: 0.48  Acc: 17.30% Average recall: 78.11% =  = 95.41
# Mult: 4 Thresh: 0.49  Acc: 16.70% Average recall: 80.21% =  = 96.91
# Mult: 4 Thresh: 0.5  Acc: 15.80% Average recall: 81.71% =  = 97.51
# Mult: 4 Thresh: 0.51  Acc: 15.02% Average recall: 82.75% =  = 97.77
# Mult: 4 Thresh: 0.52  Acc: 14.50% Average recall: 83.94% =  = 98.44
# Mult: 4 Thresh: 0.53  Acc: 13.80% Average recall: 84.43% =  = 98.22
# Mult: 4 Thresh: 0.54  Acc: 13.25% Average recall: 85.75% =  = 99.00
# Mult: 4 Thresh: 0.55  Acc: 12.68% Average recall: 86.89% =  = 99.57
# Mult: 4 Thresh: 0.6  Acc: 9.06% Average recall: 91.32% =  = 100.37
# Mult: 4 Thresh: 0.7  Acc: 2.78% Average recall: 99.70% =  = 102.47
# Mult: 4 Thresh: 0.95  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 4 Thresh: 0.96  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 4 Thresh: 0.97  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 4 Thresh: 0.975  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 4 Thresh: 0.985  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 5 ***********************************************************
# Mult: 5 Thresh: 0.2  Acc: 41.11% Average recall: 29.32% =  = 70.43
# Mult: 5 Thresh: 0.3  Acc: 25.54% Average recall: 56.12% =  = 81.66
# Mult: 5 Thresh: 0.4  Acc: 19.06% Average recall: 73.65% =  = 92.71
# Mult: 5 Thresh: 0.46  Acc: 14.70% Average recall: 83.48% =  = 98.18
# Mult: 5 Thresh: 0.47  Acc: 13.95% Average recall: 84.24% =  = 98.19
# Mult: 5 Thresh: 0.48  Acc: 13.45% Average recall: 85.26% =  = 98.71
# Mult: 5 Thresh: 0.49  Acc: 12.85% Average recall: 86.22% =  = 99.07
# Mult: 5 Thresh: 0.5  Acc: 12.26% Average recall: 87.38% =  = 99.64
# Mult: 5 Thresh: 0.51  Acc: 11.54% Average recall: 88.78% =  = 100.32
# Mult: 5 Thresh: 0.52  Acc: 10.98% Average recall: 89.25% =  = 100.23
# Mult: 5 Thresh: 0.53  Acc: 10.23% Average recall: 90.16% =  = 100.40
# Mult: 5 Thresh: 0.54  Acc: 9.44% Average recall: 90.66% =  = 100.10
# Mult: 5 Thresh: 0.55  Acc: 8.75% Average recall: 91.49% =  = 100.24
# Mult: 5 Thresh: 0.6  Acc: 4.79% Average recall: 97.75% =  = 102.53
# Mult: 5 Thresh: 0.7  Acc: 2.00% Average recall: 99.82% =  = 101.82
# Mult: 5 Thresh: 0.95  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 5 Thresh: 0.96  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 5 Thresh: 0.97  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 5 Thresh: 0.975  Acc: 1.68% Average recall: 100.00% =  = 101.68
# Mult: 5 Thresh: 0.985  Acc: 1.68% Average recall: 100.00% =  = 101.68
